# %%
import csv
import os
import sys
import subprocess
import glob
import json
import pandas
import pickle
import pprint
from pathlib import Path
from collections import defaultdict
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.Blast import NCBIXML
from Bio.SeqRecord import SeqRecord
from Bio.Blast.Applications import NcbiblastpCommandline
import pysam

# %%
def run_command(command):
    """Utility function to run a shell command. Will output stderr if anything but 0 is returned."""
    result = subprocess.run(command, shell=True, stderr=subprocess.PIPE, text=True)
    if result.returncode != 0:
        print(f"Error running command: {command}")
        print(result.stderr)
    return result

def run_minimap2(reference_fasta, query_fasta, output_sam, threads):
    """Run minimap2 against a reference and output to a sam file"""
    # Align the genome assembly against the plasmid database and output the result in SAM format
    command = f"minimap2 -t {threads} -a {reference_fasta} {query_fasta} -o {output_sam}"
    print(command)
    return run_command(command)
    
def convert_sam_to_bam(sam_file, bam_file):
    """Generate and run the command to convert SAM to BAM."""
    command = f"samtools view -Sb {sam_file} > {bam_file}"
    print(command)
    return run_command(command)

def sort_bam(bam_file, sorted_bam_file):
    """Generate and run the command to sort the BAM file."""
    command = f"samtools sort {bam_file} -o {sorted_bam_file}"
    print(command)
    return run_command(command)

def index_bam(sorted_bam_file):
    """Generate and run the command to index the sorted BAM file."""
    command = f"samtools index {sorted_bam_file}"
    print(command)
    return run_command(command)

def update_ids_in_sam(input_samfile_path, output_samfile_path, id_lookup_dict):
    # Open the input SAM file
    with pysam.AlignmentFile(input_samfile_path, "r") as samfile:
        # Open the output SAM file for writing
        with pysam.AlignmentFile(output_samfile_path, "wh", template=samfile) as outfile:
            for read in samfile:
                # Update the query name if it exists in the lookup dictionary
                if read.query_name in id_lookup_dict:
                    plasmid_name = parsing_table.get(read.query_name, {}).get('name', 'uh-oh!')
                    plasmid_id = parsing_table.get(read.query_name, {}).get('ID', 'uh-oh!')
                    plasmid_strain = parsing_table.get(read.query_name, {}).get('strain', 'uh-oh!')
                    read.query_name = f'{plasmid_id}__{plasmid_strain}__{plasmid_name}'

                # Write the modified read to the output SAM file
                outfile.write(read)

# %%
# Lets pop this pack of pickled plasmids
parsing_table = pickle.load(open(f'{parsing_tables_dir}/blast_parsing_dict.pkl', 'rb'))

# ok now let's set up the columns for our matrix and drop the synthetic vector and the ultra-rare lp21-cp9 fusion plasmid that can only be validated manually ( for now c; )
plasmids_in_db = {k : v for k, v in parsing_table.items()}
matrix_cols = []
for k in plasmids_in_db:
    matrix_cols.append(plasmids_in_db[k]['name'])
matrix_cols = list(set(matrix_cols))
matrix_cols.sort()
matrix_cols.remove('pBSV2')
#matrix_cols.remove('lp21-cp9')
print(matrix_cols)
# Out:
# ['chromosome', 'cp26', 'cp32-1', 'cp32-1+5', 'cp32-10', 'cp32-11', 'cp32-12', 'cp32-2', 'cp32-3', 'cp32-3+10', 'cp32-4', 'cp32-5', 'cp32-5+1', 'cp32-5-1', 'cp32-6', 'cp32-7', 'cp32-8', 'cp32-9', 'cp32-9-4', 'cp9', 'cp9-3', 'lp17', 'lp21', 'lp21-cp9', 'lp25', 'lp28-1', 'lp28-11', 'lp28-2', 'lp28-3', 'lp28-4', 'lp28-5', 'lp28-6', 'lp28-7', 'lp28-8', 'lp28-9', 'lp36', 'lp38', 'lp5', 'lp54', 'lp56']

# %%
VERSION='v8'
#### Define Inputs and Paths ####
# get CURRENT working directory
init_cwd = os.getcwd()
# Set working directory
source_dir = '/home/mf019/borrelia_plasmid_classifier_v3'
databases_dir = f'{source_dir}/dbs'
# Use the big ref fasta! with all of the noise!
plasmid_ref_fasta = '/home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta'
parsing_tables_dir = f'{source_dir}/parsing_tables'
# Set assemblies directory
assemblies_dir = f'{source_dir}/assemblies'
shortread_dir  = f'{assemblies_dir}/shortread'
longread_dir = f'{assemblies_dir}/longread'
# Specify where to find the annotations
shortread_annotations  = f'{shortread_dir}/annotation'
longread_annotations = f'{longread_dir}/annotation'
# okay where are we gonna dump our output?
output_dir = '/home/mf019/plasmid_caller_v4_test'
#sam n bam outputs
sam_out = f'{output_dir}/sam'
bam_out = f'{output_dir}/bam'

# %%
# find them ~~genbanks~~ *FASTAS*
sr_fnas = glob.glob(f'{shortread_annotations}/*/*.fna')
print(f'Found {len(sr_fnas)} shortread fna files')
lr_fnas = glob.glob(f'{longread_annotations}/*/*.fna')
print(f'Found {len(lr_fnas)} longread fna files')
# Out:
# Found 49 shortread fna files
# Found 49 longread fna files

# %%
print(plasmid_ref_fasta)
# Out:
# /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta

# %%
for assembly_fasta in lr_fnas:
    asm_id = os.path.basename(assembly_fasta).split('.')[0]
    temp_sam_file = f"{sam_out}/longread/temp/wp_ref_vs_{asm_id}_TEMP.sam"
    sam_file = f"{sam_out}/longread/wp_ref_vs_{asm_id}.sam"
    bam_file = f"{bam_out}/longread/wp_ref_vs_{asm_id}.bam"
    # we are aligning the references AGAINST our assembly so the output doesn't look super scuffed.
    # and so that we can look at it on a contig by contig basis to see which classification is the best hit.
    run_minimap2(assembly_fasta, plasmid_ref_fasta, temp_sam_file, 47)
    update_ids_in_sam(temp_sam_file, sam_file, parsing_table)
    convert_sam_to_bam(sam_file, bam_file)
# Out:
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI87H/URI87H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI87H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI87H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI87H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI34H/URI34H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI34H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI34H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI34H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI88H/URI88H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI88H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI88H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI88H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI33H/URI33H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI33H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI33H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI33H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT110H/UCT110H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT110H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT110H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT110H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI39H/URI39H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI39H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI39H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI39H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI91H/URI91H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI91H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI91H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI91H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT35H/UCT35H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT35H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT35H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT35H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UWI247P/UWI247P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UWI247P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UWI247P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UWI247P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI120H/URI120H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI120H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI120H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI120H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI107H/URI107H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI107H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI107H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI107H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UWI263P/UWI263P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UWI263P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UWI263P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UWI263P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI89H/URI89H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI89H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI89H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI89H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI42H/URI42H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI42H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI42H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI42H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI44H/URI44H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI44H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI44H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI44H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT109H/UCT109H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT109H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT109H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT109H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI40H/URI40H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI40H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI40H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI40H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI117H/URI117H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI117H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI117H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI117H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI47H/URI47H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI47H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI47H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI47H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI86H/URI86H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI86H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI86H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI86H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI36H/URI36H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI36H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI36H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI36H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UNY208P/UNY208P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UNY208P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UNY208P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UNY208P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/ESI26H/ESI26H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_ESI26H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_ESI26H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_ESI26H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT31H/UCT31H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT31H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT31H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT31H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI56H/URI56H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI56H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI56H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI56H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT30H/UCT30H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT30H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT30H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT30H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI103H/URI103H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI103H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI103H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI103H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT29H/UCT29H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT29H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT29H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT29H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI112H/URI112H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI112H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI112H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI112H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UWI248P/UWI248P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UWI248P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UWI248P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UWI248P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UNY203P/UNY203P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UNY203P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UNY203P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UNY203P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT96H/UCT96H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT96H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT96H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT96H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT32H/UCT32H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT32H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT32H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT32H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UNY193P/UNY193P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UNY193P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UNY193P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UNY193P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT113H/UCT113H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT113H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT113H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT113H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI93H/URI93H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI93H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI93H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI93H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UNY169P/UNY169P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UNY169P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UNY169P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UNY169P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UWI283P/UWI283P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UWI283P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UWI283P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UWI283P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI102H/URI102H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI102H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI102H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI102H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI41H/URI41H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI41H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI41H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI41H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UNY172P/UNY172P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UNY172P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UNY172P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UNY172P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UNY149P/UNY149P.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UNY149P_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UNY149P.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UNY149P.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT92H/UCT92H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT92H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT92H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT92H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI118H/URI118H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI118H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI118H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI118H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/UCT50H/UCT50H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_UCT50H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_UCT50H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_UCT50H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI101H/URI101H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI101H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI101H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI101H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI46H/URI46H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI46H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI46H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI46H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI48H/URI48H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI48H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI48H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI48H.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/longread/annotation/URI111H/URI111H.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/longread/temp/wp_ref_vs_URI111H_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/longread/wp_ref_vs_URI111H.sam > /home/mf019/plasmid_caller_v4_test/bam/longread/wp_ref_vs_URI111H.bam

# %%
for assembly_fasta in sr_fnas:
    asm_id = os.path.basename(assembly_fasta).split('.')[0]
    temp_sam_file = f"{sam_out}/shortread/temp/wp_ref_vs_{asm_id}_TEMP.sam"
    sam_file = f"{sam_out}/shortread/wp_ref_vs_{asm_id}.sam"
    bam_file = f"{bam_out}/shortread/wp_ref_vs_{asm_id}.bam"
    # we are aligning the references AGAINST our assembly so the output doesn't look super scuffed.
    # and so that we can look at it on a contig by contig basis to see which classification is the best hit.
    run_minimap2(assembly_fasta, plasmid_ref_fasta, temp_sam_file, 47)
    update_ids_in_sam(temp_sam_file, sam_file, parsing_table)
    convert_sam_to_bam(sam_file, bam_file)
# Out:
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/shortread/annotation/URI47/URI47.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/shortread/temp/wp_ref_vs_URI47_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/shortread/wp_ref_vs_URI47.sam > /home/mf019/plasmid_caller_v4_test/bam/shortread/wp_ref_vs_URI47.bam
# minimap2 -t 47 -a /home/mf019/borrelia_plasmid_classifier_v3/assemblies/shortread/annotation/URI103/URI103.fna /home/mf019/borrelia_plasmid_classifier_v3/dbs/all_plasmids.fasta -o /home/mf019/plasmid_caller_v4_test/sam/shortread/temp/wp_ref_vs_URI103_TEMP.sam
# samtools view -Sb /home/mf019/plasmid_caller_v4_test/sam/shortread/wp_ref_vs_UR