# %%
import os
import sys
import subprocess
import glob
import json
from pathlib import Path
import pandas
import pickle
import pprint
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.Blast import NCBIXML
from Bio.SeqRecord import SeqRecord
from Bio.Blast.Applications import NcbiblastpCommandline
from axe import axe
from collections import defaultdict

# %%
RUN_BLAST = True

# %%
def parse_blast_results(blast_results : str) -> dict:
    file_size = os.path.getsize(blast_results)
    if file_size == 0:
        return None
    results = {}
    with open(blast_results, "r") as f:
        blast_records = NCBIXML.parse(f)
        for record in blast_records:
            results[record.query] = []
            for alignment in record.alignments:
                for hsp in alignment.hsps:
                    results[record.query].append({'contig_id' : record.query,
                                                  'contig_len' : record.query_length,
                                                  'hit_id' : alignment.hit_id,  # Modify this line to use alignment.hit_id instead of alignment.title
                                                  'hit_title' : alignment.title,
                                                  'hit_def' : alignment.hit_def,
                                                  'hit_expect' : hsp.expect,
                                                  'hit_score' : hsp.score,
                                                  'hit_query_start' : hsp.query_start,
                                                  'hit_query_end' : hsp.query_end,
                                                  'hit_subject_start' : hsp.sbjct_start,
                                                  'hit_subject_end' : hsp.sbjct_end,
                                                  'hit_idents' : hsp.identities,
                                                  'hit_pos' : hsp.positives,
                                                  'hit_gaps' : hsp.gaps,
                                                  'hit_frame' : hsp.frame,
                                                  'hit_query' : hsp.query,
                                                  'hit_subject' : hsp.sbjct})
    return results

# %%
mjf = axe.mjf(logfile_name='plasmid_identification_v3_parsing')
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/mf019/miniconda3/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/mf019/miniconda3/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/axe/axe.py", line 74, in format
#     return formatter.format(record)
#            ^^^^^^^^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'format'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/base_events.py", line 639, in run_forever
#     self._run_once()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/base_events.py", line 1985, in _run_once
#     handle._run()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4102621/3510340624.py", line 1, in <module>
#     mjf = axe.mjf(logfile_name='plasmid_identification_v3_parsing')
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/axe/axe.py", line 211, in __init__
#     self.logger.log(msg=f'FileHandler for {self.logfile} is now online at level: {self.logfile_level}', level=100)
# Message: 'FileHandler for plasmid_identification_v3_parsing___2024-04-26__1901__.log is now online at level: 10'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/mf019/miniconda3/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/mf019/miniconda3/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/axe/axe.py", line 74, in format
#     return formatter.format(record)
#            ^^^^^^^^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'format'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/base_events.py", line 639, in run_forever
#     self._run_once()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/base_events.py", line 1985, in _run_once
#     handle._run()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4102621/3510340624.py", line 1, in <module>
#     mjf = axe.mjf(logfile_name='plasmid_identification_v3_parsing')
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/axe/axe.py", line 223, in __init__
#     self.logger.log(msg=f'Console StreamHandler is now online at level: {self.console_level}', level=100)
# Message: 'Console StreamHandler is now online at level: 10'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/mf019/miniconda3/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/mf019/miniconda3/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/axe/axe.py", line 74, in format
#     return formatter.format(record)
#            ^^^^^^^^^^^^^^^^
# AttributeError: 'tuple' object has no attribute 'format'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/base_events.py", line 639, in run_forever
#     self._run_once()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/base_events.py", line 1985, in _run_once
#     handle._run()
#   File "/home/mf019/miniconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 359, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 446, in do_execute
#     res = shell.run_cell(
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_4102621/3510340624.py", line 1, in <module>
#     mjf = axe.mjf(logfile_name='plasmid_identification_v3_parsing')
#   File "/home/mf019/miniconda3/lib/python3.12/site-packages/axe/axe.py", line 223, in __init__
#     self.logger.log(msg=f'Console StreamHandler is now online at level: {self.console_level}', level=100)
# Message: 'Console StreamHandler is now online at level: 10'
# Arguments: ()

# %%
testing_set_file = 'dbs/Minimal-PF32-testor-set-March2021.faa'

# %%
# get working directory
init_cwd = os.getcwd()
# Set working directory
working_dir = '/home/mf019/borrelia_plasmid_classifier_v3'
# path out the databases
databases_dir = f'{working_dir}/dbs'
whole_plasmid_db = f'{databases_dir}/plasmid_db/plasmid_db'
pf32_db = f'{databases_dir}/pf32_db/pf32'
# lets specify where parsing tables are to be found!
parsing_tables_dir = f'{working_dir}/parsing_tables'
# set assemblies directory # DO I WANT TO ARGV THIS?
assemblies_dir = '/home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only' #f'{working_dir}/assemblies'
shortread_dir  = f'{assemblies_dir}/shortread'
longread_dir = f'{assemblies_dir}/longread'
shortread_contigs  = f'{shortread_dir}/contigs'
longread_contigs = f'{longread_dir}/contigs'
shortread_annotations  = f'{shortread_dir}/annotation'
longread_annotations = f'{longread_dir}/annotation'
output_dir = f'{working_dir}/output'
blast_results_dir = f'{output_dir}/blast_results'
pf32_blast_results = f'{blast_results_dir}/pf32'
plasmid_blast_results = f'{blast_results_dir}/whole_plasmid'

# %%
print(f'Working directory: {working_dir}')
print(f'Databases directory: {databases_dir}')
print(f'Plasmid database: {whole_plasmid_db}')
print(f'PF32 database: {pf32_db}')
print(f'Parsing tables directory: {parsing_tables_dir}')
print(f'Assemblies directory: {assemblies_dir}')
print(f'Shortread directory: {shortread_dir}')
print(f'Longread directory: {longread_dir}')
print(f'Shortread contigs directory: {shortread_contigs}')
print(f'Shortread annotations directory: {shortread_annotations}')
print(f'Longread contigs directory: {longread_contigs}')
print(f'Longread annotations directory: {longread_annotations}')
print(f'Output directory: {output_dir}')
print(f'Whole contig blast results directory: {blast_results_dir}')
print(f'PF32 Blast results: {pf32_blast_results}')
# Out:
# Working directory: /home/mf019/borrelia_plasmid_classifier_v3
# Databases directory: /home/mf019/borrelia_plasmid_classifier_v3/dbs
# Plasmid database: /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db
# PF32 database: /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32
# Parsing tables directory: /home/mf019/borrelia_plasmid_classifier_v3/parsing_tables
# Assemblies directory: /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only
# Shortread directory: /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/shortread
# Longread directory: /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread
# Shortread contigs directory: /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/shortread/contigs
# Shortread annotations directory: /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/shortread/annotation
# Longread contigs directory: /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Longread annotations directory: /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/annotation
# Output directory: /home/mf019/borrelia_plasmid_classifier_v3/output
# Whole contig blast results directory: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results
# PF32 Blast results: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32

# %%
# get annotations for each method
sr_gbs = glob.glob(f'{shortread_annotations}/*/*.gbff')
print(f'Found {len(sr_gbs)} shortread gbff files')
lr_gbs = glob.glob(f'{longread_annotations}/*/*.gbff')
print(f'Found {len(lr_gbs)} longread gbff files')
# Out:
# Found 49 shortread gbff files
# Found 49 longread gbff files

# %%
if not os.path.exists(f'{output_dir}/assembly_dict.pkl'):
    assembly_dict = defaultdict(dict)
    for assembly in lr_gbs: # iterate through each longread assembly
        assembly_name = Path(assembly).stem # get the name of the assembly
        print(f'Processing assembly: {assembly_name}')
        if assembly_name.endswith(('H','P')):
            assembly_name = assembly_name[:-1] # chop last character off for dict key
        assembly_dict[assembly_name] = defaultdict(dict)
        assembly_dict[assembly_name]['longread'] = defaultdict(dict)
        with open(assembly, 'r') as f: # get longread contigs and annotations
            num_contigs = 0
            num_genes = 0
            for contig in SeqIO.parse(handle=f, format='genbank'):
                num_contigs += 1
                contig_id = contig.name
                print(contig_id)
                assembly_dict[assembly_name]['longread'][contig_id]['seq'] = contig.seq
                assembly_dict[assembly_name]['longread'][contig_id]['annotations'] = contig.annotations
                assembly_dict[assembly_name]['longread'][contig_id]['features'] = contig.features
                if len(contig.features) > 0:
                    for feature in contig.features:
                        if feature.type == 'CDS':
                            num_genes += 1
            print(f'longread:{assembly_name}[\'longread\'] has {num_contigs} contigs')
            print(f'longread: {assembly_name}[\'longread\'] has {num_genes} annotated genes')

        # now we need to get the shortread contigs and annotations if they exist.
        shortread_file = f'{shortread_annotations}/{assembly_name}.gbff'
        if shortread_file in sr_gbs:
            print(f'Found shortread annotations for {assembly_name}')
            assembly_dict[assembly_name]['shortread'] = defaultdict(dict)
            with open(shortread_file, 'r') as fi:
                num_genes = 0
                num_contigs = 0
                for scontig in SeqIO.parse(handle=fi, format='genbank'):
                    num_contigs += 1
                    scontig_id = scontig.id
                    #print(scontig_id)
                    assembly_dict[assembly_name]['shortread'][scontig_id]['seq'] = scontig.seq
                    assembly_dict[assembly_name]['shortread'][scontig_id]['annotations'] = scontig.annotations
                    assembly_dict[assembly_name]['shortread'][scontig_id]['features'] = scontig.features
                    if len(scontig.features) > 0:
                        for feature in scontig.features:
                            if feature.type == 'CDS':
                                num_genes += 1
                    # now we need to blast this contig against the pf32 and whole plasmid databases
                    # we will need to save these results in a dictionary
            print(f'shortread:{assembly_name} has {num_contigs} contigs')
            print(f'shortread: {assembly_name} has {num_genes} annotated genes')
        else:
            assembly_dict[assembly_name]['shortread'] = 'NOT AVAILABLE'
            print(f'No shortread annotations found for {assembly_name}')
    print('dictionary construction complete! pickling!')
    pickle.dump(assembly_dict, open(f'{output_dir}/assembly_dict_v3.pkl', 'wb'))
    print(f'dictionary pickled to: {output_dir}/assembly_dict_v3.pkl')
# Out:
# Processing assembly: URI87H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# longread:URI87['longread'] has 66 contigs
# longread: URI87['longread'] has 1466 annotated genes
# No shortread annotations found for URI87
# Processing assembly: URI34H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# longread:URI34['longread'] has 79 contigs
# longread: URI34['longread'] has 1295 annotated genes
# No shortread annotations found for URI34
# Processing assembly: URI88H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# longread:URI88['longread'] has 33 contigs
# longread: URI88['longread'] has 1502 annotated genes
# No shortread annotations found for URI88
# Processing assembly: URI33H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# longread:URI33['longread'] has 44 contigs
# longread: URI33['longread'] has 1272 annotated genes
# No shortread annotations found for URI33
# Processing assembly: UCT110H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# contig000090
# contig000091
# contig000092
# contig000093
# contig000094
# contig000095
# contig000096
# contig000097
# contig000098
# contig000099
# contig000100
# contig000101
# contig000102
# contig000103
# contig000104
# contig000105
# contig000106
# contig000107
# contig000108
# contig000109
# contig000110
# contig000111
# contig000112
# contig000113
# contig000114
# longread:UCT110['longread'] has 114 contigs
# longread: UCT110['longread'] has 1343 annotated genes
# No shortread annotations found for UCT110
# Processing assembly: URI39H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# longread:URI39['longread'] has 28 contigs
# longread: URI39['longread'] has 1542 annotated genes
# No shortread annotations found for URI39
# Processing assembly: URI91H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# longread:URI91['longread'] has 26 contigs
# longread: URI91['longread'] has 1574 annotated genes
# No shortread annotations found for URI91
# Processing assembly: UCT35H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# longread:UCT35['longread'] has 33 contigs
# longread: UCT35['longread'] has 1278 annotated genes
# No shortread annotations found for UCT35
# Processing assembly: UWI247P
# MC104_chr
# MC104_cp26
# MC104_cp32-1
# MC104_cp32-11
# MC104_cp32-3
# MC104_cp32-4
# MC104_cp32-6
# MC104_cp32-7
# MC104_lp17
# MC104_lp25
# MC104_lp28-1
# MC104_lp28-3
# MC104_lp28-4
# MC104_lp28-5
# MC104_lp36
# MC104_lp38
# MC104_lp54
# longread:UWI247['longread'] has 17 contigs
# longread: UWI247['longread'] has 1300 annotated genes
# No shortread annotations found for UWI247
# Processing assembly: URI120H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# contig000090
# contig000091
# contig000092
# contig000093
# contig000094
# contig000095
# contig000096
# contig000097
# contig000098
# contig000099
# contig000100
# contig000101
# contig000102
# contig000103
# contig000104
# contig000105
# longread:URI120['longread'] has 105 contigs
# longread: URI120['longread'] has 1544 annotated genes
# No shortread annotations found for URI120
# Processing assembly: URI107H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# longread:URI107['longread'] has 49 contigs
# longread: URI107['longread'] has 1479 annotated genes
# No shortread annotations found for URI107
# Processing assembly: UWI263P
# MC123_chr
# MC123_cp26
# MC123_cp32-11
# MC123_cp32-12
# MC123_cp32-4
# MC123_cp32-5
# MC123_cp32-6
# MC123_cp32-7
# MC123_cp32-9
# MC123_cp9
# MC123_lp17
# MC123_lp25
# MC123_lp28-1
# MC123_lp28-3
# MC123_lp28-4
# MC123_lp28-5
# MC123_lp36
# MC123_lp38
# MC123_lp54
# longread:UWI263['longread'] has 19 contigs
# longread: UWI263['longread'] has 1372 annotated genes
# No shortread annotations found for UWI263
# Processing assembly: URI89H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# longread:URI89['longread'] has 85 contigs
# longread: URI89['longread'] has 1526 annotated genes
# No shortread annotations found for URI89
# Processing assembly: URI42H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# longread:URI42['longread'] has 74 contigs
# longread: URI42['longread'] has 1422 annotated genes
# No shortread annotations found for URI42
# Processing assembly: URI44H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# longread:URI44['longread'] has 75 contigs
# longread: URI44['longread'] has 1341 annotated genes
# No shortread annotations found for URI44
# Processing assembly: UCT109H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# longread:UCT109['longread'] has 28 contigs
# longread: UCT109['longread'] has 1438 annotated genes
# No shortread annotations found for UCT109
# Processing assembly: URI40H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# longread:URI40['longread'] has 82 contigs
# longread: URI40['longread'] has 1470 annotated genes
# No shortread annotations found for URI40
# Processing assembly: URI117H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# contig000090
# contig000091
# contig000092
# contig000093
# contig000094
# contig000095
# contig000096
# contig000097
# contig000098
# contig000099
# contig000100
# contig000101
# contig000102
# contig000103
# contig000104
# contig000105
# contig000106
# contig000107
# contig000108
# contig000109
# contig000110
# contig000111
# contig000112
# contig000113
# contig000114
# contig000115
# contig000116
# contig000117
# contig000118
# contig000119
# contig000120
# contig000121
# contig000122
# contig000123
# contig000124
# contig000125
# contig000126
# contig000127
# contig000128
# contig000129
# contig000130
# contig000131
# contig000132
# contig000133
# contig000134
# contig000135
# contig000136
# contig000137
# contig000138
# contig000139
# contig000140
# contig000141
# contig000142
# contig000143
# contig000144
# contig000145
# contig000146
# contig000147
# contig000148
# contig000149
# contig000150
# contig000151
# contig000152
# contig000153
# contig000154
# contig000155
# contig000156
# contig000157
# contig000158
# contig000159
# contig000160
# longread:URI117['longread'] has 160 contigs
# longread: URI117['longread'] has 1299 annotated genes
# No shortread annotations found for URI117
# Processing assembly: URI47H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# longread:URI47['longread'] has 29 contigs
# longread: URI47['longread'] has 1477 annotated genes
# No shortread annotations found for URI47
# Processing assembly: URI86H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# longread:URI86['longread'] has 88 contigs
# longread: URI86['longread'] has 1329 annotated genes
# No shortread annotations found for URI86
# Processing assembly: URI36H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# longread:URI36['longread'] has 53 contigs
# longread: URI36['longread'] has 1423 annotated genes
# No shortread annotations found for URI36
# Processing assembly: UNY208P
# MR641_chr
# MR641_cp26
# MR641_cp32-1
# MR641_cp32-11
# MR641_cp32-12
# MR641_cp32-4
# MR641_cp32-5
# MR641_cp32-7
# MR641_cp32-8
# MR641_cp32-x
# MR641_lp17
# MR641_lp25
# MR641_lp28-1
# MR641_lp28-3
# MR641_lp28-4
# MR641_lp28-5
# MR641_lp28-6
# MR641_lp36
# MR641_lp54
# longread:UNY208['longread'] has 19 contigs
# longread: UNY208['longread'] has 1376 annotated genes
# No shortread annotations found for UNY208
# Processing assembly: ESI26H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# longread:ESI26['longread'] has 64 contigs
# longread: ESI26['longread'] has 1213 annotated genes
# No shortread annotations found for ESI26
# Processing assembly: UCT31H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# longread:UCT31['longread'] has 32 contigs
# longread: UCT31['longread'] has 1514 annotated genes
# No shortread annotations found for UCT31
# Processing assembly: URI56H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# contig000090
# contig000091
# contig000092
# contig000093
# contig000094
# contig000095
# contig000096
# contig000097
# contig000098
# contig000099
# contig000100
# contig000101
# contig000102
# contig000103
# contig000104
# contig000105
# contig000106
# contig000107
# contig000108
# contig000109
# contig000110
# contig000111
# contig000112
# contig000113
# contig000114
# contig000115
# contig000116
# contig000117
# contig000118
# contig000119
# contig000120
# contig000121
# contig000122
# contig000123
# contig000124
# contig000125
# contig000126
# contig000127
# contig000128
# contig000129
# contig000130
# contig000131
# contig000132
# contig000133
# contig000134
# contig000135
# contig000136
# contig000137
# contig000138
# contig000139
# contig000140
# contig000141
# contig000142
# contig000143
# contig000144
# contig000145
# contig000146
# contig000147
# contig000148
# contig000149
# contig000150
# contig000151
# contig000152
# contig000153
# contig000154
# contig000155
# contig000156
# contig000157
# contig000158
# contig000159
# contig000160
# contig000161
# contig000162
# contig000163
# contig000164
# contig000165
# contig000166
# contig000167
# contig000168
# contig000169
# contig000170
# contig000171
# contig000172
# contig000173
# contig000174
# contig000175
# contig000176
# contig000177
# contig000178
# contig000179
# contig000180
# contig000181
# contig000182
# contig000183
# contig000184
# contig000185
# contig000186
# contig000187
# contig000188
# contig000189
# contig000190
# contig000191
# contig000192
# contig000193
# contig000194
# contig000195
# contig000196
# contig000197
# contig000198
# contig000199
# contig000200
# contig000201
# contig000202
# contig000203
# contig000204
# contig000205
# contig000206
# contig000207
# contig000208
# contig000209
# contig000210
# contig000211
# contig000212
# contig000213
# contig000214
# contig000215
# contig000216
# contig000217
# contig000218
# contig000219
# contig000220
# contig000221
# contig000222
# contig000223
# contig000224
# contig000225
# contig000226
# contig000227
# contig000228
# contig000229
# contig000230
# longread:URI56['longread'] has 230 contigs
# longread: URI56['longread'] has 1187 annotated genes
# No shortread annotations found for URI56
# Processing assembly: UCT30H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# longread:UCT30['longread'] has 89 contigs
# longread: UCT30['longread'] has 1385 annotated genes
# No shortread annotations found for UCT30
# Processing assembly: URI103H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# longread:URI103['longread'] has 56 contigs
# longread: URI103['longread'] has 1424 annotated genes
# No shortread annotations found for URI103
# Processing assembly: UCT29H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# longread:UCT29['longread'] has 24 contigs
# longread: UCT29['longread'] has 1547 annotated genes
# No shortread annotations found for UCT29
# Processing assembly: URI112H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# longread:URI112['longread'] has 85 contigs
# longread: URI112['longread'] has 1366 annotated genes
# No shortread annotations found for URI112
# Processing assembly: UWI248P
# MC105_chr
# MC105_cp26
# MC105_cp32-1
# MC105_cp32-11
# MC105_cp32-12
# MC105_cp32-3
# MC105_cp32-4
# MC105_cp32-6
# MC105_cp32-7
# MC105_lp17
# MC105_lp25
# MC105_lp28-1
# MC105_lp28-3
# MC105_lp28-4
# MC105_lp28-5
# MC105_lp36
# MC105_lp38
# MC105_lp54
# longread:UWI248['longread'] has 18 contigs
# longread: UWI248['longread'] has 1337 annotated genes
# No shortread annotations found for UWI248
# Processing assembly: UNY203P
# MR616_chr
# MR616_cp26
# MR616_cp32-10
# MR616_cp32-12
# MR616_cp32-4
# MR616_cp32-5
# MR616_cp32-6
# MR616_cp32-7
# MR616_cp9
# MR616_lp17
# MR616_lp28-3
# MR616_lp28-5
# MR616_lp28-6
# MR616_lp36
# MR616_lp38
# MR616_lp5
# MR616_lp54
# longread:UNY203['longread'] has 17 contigs
# longread: UNY203['longread'] has 1289 annotated genes
# No shortread annotations found for UNY203
# Processing assembly: UCT96H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# longread:UCT96['longread'] has 35 contigs
# longread: UCT96['longread'] has 1451 annotated genes
# No shortread annotations found for UCT96
# Processing assembly: UCT32H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# longread:UCT32['longread'] has 57 contigs
# longread: UCT32['longread'] has 1459 annotated genes
# No shortread annotations found for UCT32
# Processing assembly: UNY193P
# B477_chr
# B477_cp26
# B477_cp32-10
# B477_cp32-12
# B477_cp32-5
# B477_cp32-6
# B477_cp32-7
# B477_cp9
# B477_lp17
# B477_lp25
# B477_lp28-3
# B477_lp28-4
# B477_lp28-6
# B477_lp28-7
# B477_lp28-x
# B477_lp36
# B477_lp38
# B477_lp54
# B477_lp5
# longread:UNY193['longread'] has 19 contigs
# longread: UNY193['longread'] has 1358 annotated genes
# No shortread annotations found for UNY193
# Processing assembly: UCT113H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# contig000090
# contig000091
# contig000092
# contig000093
# contig000094
# contig000095
# contig000096
# contig000097
# contig000098
# contig000099
# contig000100
# contig000101
# contig000102
# contig000103
# contig000104
# contig000105
# contig000106
# contig000107
# contig000108
# contig000109
# contig000110
# contig000111
# contig000112
# contig000113
# contig000114
# contig000115
# contig000116
# contig000117
# contig000118
# contig000119
# contig000120
# contig000121
# contig000122
# contig000123
# contig000124
# contig000125
# contig000126
# contig000127
# contig000128
# contig000129
# contig000130
# contig000131
# contig000132
# contig000133
# contig000134
# contig000135
# contig000136
# contig000137
# contig000138
# contig000139
# contig000140
# contig000141
# contig000142
# contig000143
# contig000144
# contig000145
# contig000146
# contig000147
# contig000148
# contig000149
# contig000150
# contig000151
# contig000152
# contig000153
# contig000154
# contig000155
# contig000156
# contig000157
# contig000158
# contig000159
# contig000160
# contig000161
# contig000162
# contig000163
# contig000164
# contig000165
# contig000166
# contig000167
# contig000168
# contig000169
# contig000170
# contig000171
# contig000172
# contig000173
# contig000174
# contig000175
# contig000176
# contig000177
# contig000178
# contig000179
# contig000180
# contig000181
# contig000182
# contig000183
# contig000184
# contig000185
# contig000186
# contig000187
# contig000188
# contig000189
# contig000190
# contig000191
# contig000192
# contig000193
# contig000194
# contig000195
# contig000196
# contig000197
# contig000198
# contig000199
# contig000200
# contig000201
# contig000202
# contig000203
# contig000204
# contig000205
# contig000206
# contig000207
# contig000208
# contig000209
# contig000210
# contig000211
# contig000212
# contig000213
# contig000214
# contig000215
# contig000216
# contig000217
# contig000218
# contig000219
# contig000220
# contig000221
# contig000222
# contig000223
# contig000224
# contig000225
# contig000226
# contig000227
# contig000228
# contig000229
# contig000230
# contig000231
# contig000232
# contig000233
# contig000234
# contig000235
# contig000236
# contig000237
# contig000238
# contig000239
# contig000240
# contig000241
# contig000242
# contig000243
# contig000244
# contig000245
# contig000246
# contig000247
# contig000248
# contig000249
# contig000250
# contig000251
# contig000252
# contig000253
# longread:UCT113['longread'] has 253 contigs
# longread: UCT113['longread'] has 1189 annotated genes
# No shortread annotations found for UCT113
# Processing assembly: URI93H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# longread:URI93['longread'] has 29 contigs
# longread: URI93['longread'] has 1426 annotated genes
# No shortread annotations found for URI93
# Processing assembly: UNY169P
# B348_chr
# B348_cp26
# B348_cp32-10
# B348_cp32-12
# B348_cp32-4
# B348_cp32-5
# B348_cp32-7
# B348_cp32-9
# B348_cp9
# B348_lp17
# B348_lp25
# B348_lp28-2
# B348_lp28-3
# B348_lp28-4
# B348_lp36
# B348_lp38
# B348_lp54
# longread:UNY169['longread'] has 17 contigs
# longread: UNY169['longread'] has 1303 annotated genes
# No shortread annotations found for UNY169
# Processing assembly: UWI283P
# MC149_chr
# MC149_cp26
# MC149_cp32-1
# MC149_cp32-12
# MC149_cp32-2
# MC149_cp32-4
# MC149_cp32-5
# MC149_cp32-9
# MC149_lp17
# MC149_lp25
# MC149_lp28-2
# MC149_lp28-3
# MC149_lp28-4
# MC149_lp28-5
# MC149_lp36
# MC149_lp54
# longread:UWI283['longread'] has 16 contigs
# longread: UWI283['longread'] has 1277 annotated genes
# No shortread annotations found for UWI283
# Processing assembly: URI102H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# longread:URI102['longread'] has 44 contigs
# longread: URI102['longread'] has 1392 annotated genes
# No shortread annotations found for URI102
# Processing assembly: URI41H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# longread:URI41['longread'] has 84 contigs
# longread: URI41['longread'] has 1437 annotated genes
# No shortread annotations found for URI41
# Processing assembly: UNY172P
# B356_chr
# B356_cp26
# B356_cp32-12
# B356_cp32-4
# B356_cp32-5+1
# B356_cp32-5
# B356_cp32-7
# B356_cp32-9
# B356_lp17
# B356_lp25
# B356_lp28-2
# B356_lp28-3
# B356_lp28-4
# B356_lp36
# B356_lp38
# B356_lp54
# longread:UNY172['longread'] has 16 contigs
# longread: UNY172['longread'] has 1298 annotated genes
# No shortread annotations found for UNY172
# Processing assembly: UNY149P
# B247_chr
# B247_cp26
# B247_cp32-11
# B247_cp32-3
# B247_cp32-4
# B247_cp32-5
# B247_cp32-6
# B247_cp32-7
# B247_cp32-9
# B247_lp17
# B247_lp25
# B247_lp28-1
# B247_lp28-3
# B247_lp28-4
# B247_lp28-5
# B247_lp28-6
# B247_lp36
# B247_lp38
# B247_lp54
# longread:UNY149['longread'] has 19 contigs
# longread: UNY149['longread'] has 1389 annotated genes
# No shortread annotations found for UNY149
# Processing assembly: UCT92H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# longread:UCT92['longread'] has 62 contigs
# longread: UCT92['longread'] has 1512 annotated genes
# No shortread annotations found for UCT92
# Processing assembly: URI118H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# contig000090
# contig000091
# contig000092
# contig000093
# contig000094
# contig000095
# contig000096
# contig000097
# contig000098
# contig000099
# contig000100
# contig000101
# contig000102
# contig000103
# contig000104
# contig000105
# contig000106
# contig000107
# contig000108
# contig000109
# longread:URI118['longread'] has 109 contigs
# longread: URI118['longread'] has 1317 annotated genes
# No shortread annotations found for URI118
# Processing assembly: UCT50H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# contig000090
# longread:UCT50['longread'] has 90 contigs
# longread: UCT50['longread'] has 1284 annotated genes
# No shortread annotations found for UCT50
# Processing assembly: URI101H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# longread:URI101['longread'] has 32 contigs
# longread: URI101['longread'] has 1513 annotated genes
# No shortread annotations found for URI101
# Processing assembly: URI46H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# contig000024
# contig000025
# contig000026
# contig000027
# contig000028
# contig000029
# contig000030
# contig000031
# contig000032
# contig000033
# contig000034
# contig000035
# contig000036
# contig000037
# contig000038
# contig000039
# contig000040
# contig000041
# contig000042
# contig000043
# contig000044
# contig000045
# contig000046
# contig000047
# contig000048
# contig000049
# contig000050
# contig000051
# contig000052
# contig000053
# contig000054
# contig000055
# contig000056
# contig000057
# contig000058
# contig000059
# contig000060
# contig000061
# contig000062
# contig000063
# contig000064
# contig000065
# contig000066
# contig000067
# contig000068
# contig000069
# contig000070
# contig000071
# contig000072
# contig000073
# contig000074
# contig000075
# contig000076
# contig000077
# contig000078
# contig000079
# contig000080
# contig000081
# contig000082
# contig000083
# contig000084
# contig000085
# contig000086
# contig000087
# contig000088
# contig000089
# contig000090
# contig000091
# contig000092
# contig000093
# contig000094
# contig000095
# longread:URI46['longread'] has 95 contigs
# longread: URI46['longread'] has 1363 annotated genes
# No shortread annotations found for URI46
# Processing assembly: URI48H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# longread:URI48['longread'] has 22 contigs
# longread: URI48['longread'] has 1323 annotated genes
# No shortread annotations found for URI48
# Processing assembly: URI111H
# contig000001
# contig000002
# contig000003
# contig000004
# contig000005
# contig000006
# contig000007
# contig000008
# contig000009
# contig000010
# contig000011
# contig000012
# contig000013
# contig000014
# contig000015
# contig000016
# contig000017
# contig000018
# contig000019
# contig000020
# contig000021
# contig000022
# contig000023
# longread:URI111['longread'] has 23 contigs
# longread: URI111['longread'] has 1513 annotated genes
# No shortread annotations found for URI111
# dictionary construction complete! pickling!
# dictionary pickled to: /home/mf019/borrelia_plasmid_classifier_v3/output/assembly_dict_v3.pkl

# %%
if RUN_BLAST is True:
    for isolate in assembly_dict:
        input_files = [] # empty list to store input files
        lr_data = assembly_dict[isolate]['longread']
        sr_data = assembly_dict[isolate]['shortread']
        lr_id = isolate # since we're operating on lr first
        input_files.append(f'{longread_contigs}/{lr_id}.fasta') # add lr contigs to list
        if sr_data == 'NOT AVAILABLE':
            print(f'No shortread annotations found for {isolate}')
            sr_id = None
        else:
            sr_id = isolate[:-1:]
            input_files.append(f'{shortread_contigs}/{sr_id}.fasta')
        print(f'setting up blast commands for {isolate}')
        for file in input_files:
            name = Path(file).stem
            path = os.path.dirname(file)
            print(path)
            bind_path = f'/tmp/{name}.fasta'
            wp_output_file = f'{plasmid_blast_results}/{name}_whole_plasmid.xml'
            wp_blast_cmd = f'blastn -query {bind_path} -task "blastn" '
            wp_blast_cmd += f'-db {whole_plasmid_db} '
            wp_blast_cmd += f' -out {wp_output_file} '
            wp_blast_cmd += "-evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5"
            print(f'Running blast command:\n{wp_blast_cmd}')
            #subprocess.run(f'singularity exec --bind {path}:/tmp containers/blast.simg {wp_blast_cmd}', shell=True, check=False) # run it
            print(f'whole plasmid blast results written to: {wp_output_file}')
            print(f'setting up blast command for pf32 blast')
            pf_output_file = f'{pf32_blast_results}/{name}_pf32.xml'
            pf_blast_cmd = f'blastx -query {bind_path} -task "blastx" '
            pf_blast_cmd += f'-db {pf32_db} '
            pf_blast_cmd += f' -out {pf_output_file} '
            pf_blast_cmd += "-evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5"
            print(f'Running blast command:\n{pf_blast_cmd}')
            #subprocess.run(f'singularity exec --bind {path}:/tmp containers/blast.simg {pf_blast_cmd}', shell=True, check=False) # run it, but don't check for errors to avoid stopping the script
            print(f'pf32 blast results written to: {pf_output_file}')
    print('saddle up, we are done here!')
else:
    print('Blast already run, skipping blast')
# Out:
# No shortread annotations found for URI87
# setting up blast commands for URI87
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI87.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI87_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI87_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI87.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI87_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI87_pf32.xml
# No shortread annotations found for URI34
# setting up blast commands for URI34
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI34.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI34_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI34_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI34.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI34_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI34_pf32.xml
# No shortread annotations found for URI88
# setting up blast commands for URI88
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI88.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI88_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI88_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI88.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI88_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI88_pf32.xml
# No shortread annotations found for URI33
# setting up blast commands for URI33
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI33.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI33_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI33_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI33.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI33_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI33_pf32.xml
# No shortread annotations found for UCT110
# setting up blast commands for UCT110
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT110.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT110_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT110_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT110.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT110_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT110_pf32.xml
# No shortread annotations found for URI39
# setting up blast commands for URI39
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI39.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI39_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI39_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI39.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI39_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI39_pf32.xml
# No shortread annotations found for URI91
# setting up blast commands for URI91
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI91.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI91_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI91_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI91.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI91_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI91_pf32.xml
# No shortread annotations found for UCT35
# setting up blast commands for UCT35
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT35.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT35_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT35_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT35.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT35_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT35_pf32.xml
# No shortread annotations found for UWI247
# setting up blast commands for UWI247
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UWI247.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UWI247_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UWI247_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UWI247.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UWI247_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UWI247_pf32.xml
# No shortread annotations found for URI120
# setting up blast commands for URI120
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI120.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI120_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI120_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI120.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI120_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI120_pf32.xml
# No shortread annotations found for URI107
# setting up blast commands for URI107
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI107.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI107_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI107_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI107.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI107_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI107_pf32.xml
# No shortread annotations found for UWI263
# setting up blast commands for UWI263
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UWI263.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UWI263_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UWI263_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UWI263.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UWI263_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UWI263_pf32.xml
# No shortread annotations found for URI89
# setting up blast commands for URI89
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI89.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI89_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI89_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI89.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI89_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI89_pf32.xml
# No shortread annotations found for URI42
# setting up blast commands for URI42
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI42.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI42_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI42_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI42.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI42_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI42_pf32.xml
# No shortread annotations found for URI44
# setting up blast commands for URI44
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI44.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI44_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI44_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI44.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI44_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI44_pf32.xml
# No shortread annotations found for UCT109
# setting up blast commands for UCT109
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT109.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT109_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT109_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT109.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT109_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT109_pf32.xml
# No shortread annotations found for URI40
# setting up blast commands for URI40
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI40.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI40_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI40_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI40.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI40_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI40_pf32.xml
# No shortread annotations found for URI117
# setting up blast commands for URI117
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI117.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI117_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI117_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI117.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI117_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI117_pf32.xml
# No shortread annotations found for URI47
# setting up blast commands for URI47
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI47.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI47_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI47_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI47.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI47_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI47_pf32.xml
# No shortread annotations found for URI86
# setting up blast commands for URI86
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI86.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI86_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI86_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI86.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI86_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI86_pf32.xml
# No shortread annotations found for URI36
# setting up blast commands for URI36
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI36.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI36_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI36_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI36.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI36_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI36_pf32.xml
# No shortread annotations found for UNY208
# setting up blast commands for UNY208
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UNY208.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY208_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY208_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UNY208.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY208_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY208_pf32.xml
# No shortread annotations found for ESI26
# setting up blast commands for ESI26
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/ESI26.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/ESI26_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/ESI26_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/ESI26.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/ESI26_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/ESI26_pf32.xml
# No shortread annotations found for UCT31
# setting up blast commands for UCT31
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT31.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT31_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT31_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT31.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT31_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT31_pf32.xml
# No shortread annotations found for URI56
# setting up blast commands for URI56
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI56.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI56_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI56_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI56.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI56_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI56_pf32.xml
# No shortread annotations found for UCT30
# setting up blast commands for UCT30
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT30.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT30_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT30_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT30.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT30_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT30_pf32.xml
# No shortread annotations found for URI103
# setting up blast commands for URI103
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI103.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI103_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI103_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI103.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI103_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI103_pf32.xml
# No shortread annotations found for UCT29
# setting up blast commands for UCT29
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT29.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT29_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT29_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT29.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT29_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT29_pf32.xml
# No shortread annotations found for URI112
# setting up blast commands for URI112
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI112.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI112_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI112_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI112.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI112_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI112_pf32.xml
# No shortread annotations found for UWI248
# setting up blast commands for UWI248
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UWI248.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UWI248_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UWI248_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UWI248.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UWI248_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UWI248_pf32.xml
# No shortread annotations found for UNY203
# setting up blast commands for UNY203
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UNY203.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY203_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY203_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UNY203.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY203_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY203_pf32.xml
# No shortread annotations found for UCT96
# setting up blast commands for UCT96
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT96.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT96_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT96_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT96.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT96_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT96_pf32.xml
# No shortread annotations found for UCT32
# setting up blast commands for UCT32
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT32.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT32_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT32_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT32.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT32_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT32_pf32.xml
# No shortread annotations found for UNY193
# setting up blast commands for UNY193
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UNY193.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY193_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY193_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UNY193.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY193_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY193_pf32.xml
# No shortread annotations found for UCT113
# setting up blast commands for UCT113
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT113.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT113_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT113_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT113.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT113_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT113_pf32.xml
# No shortread annotations found for URI93
# setting up blast commands for URI93
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI93.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI93_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI93_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI93.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI93_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI93_pf32.xml
# No shortread annotations found for UNY169
# setting up blast commands for UNY169
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UNY169.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY169_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY169_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UNY169.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY169_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY169_pf32.xml
# No shortread annotations found for UWI283
# setting up blast commands for UWI283
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UWI283.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UWI283_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UWI283_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UWI283.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UWI283_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UWI283_pf32.xml
# No shortread annotations found for URI102
# setting up blast commands for URI102
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI102.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI102_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI102_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI102.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI102_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI102_pf32.xml
# No shortread annotations found for URI41
# setting up blast commands for URI41
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI41.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI41_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI41_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI41.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI41_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI41_pf32.xml
# No shortread annotations found for UNY172
# setting up blast commands for UNY172
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UNY172.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY172_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY172_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UNY172.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY172_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY172_pf32.xml
# No shortread annotations found for UNY149
# setting up blast commands for UNY149
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UNY149.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY149_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UNY149_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UNY149.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY149_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UNY149_pf32.xml
# No shortread annotations found for UCT92
# setting up blast commands for UCT92
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT92.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT92_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT92_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT92.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT92_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT92_pf32.xml
# No shortread annotations found for URI118
# setting up blast commands for URI118
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI118.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI118_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI118_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI118.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI118_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI118_pf32.xml
# No shortread annotations found for UCT50
# setting up blast commands for UCT50
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/UCT50.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT50_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/UCT50_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/UCT50.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT50_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/UCT50_pf32.xml
# No shortread annotations found for URI101
# setting up blast commands for URI101
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI101.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI101_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI101_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI101.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI101_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI101_pf32.xml
# No shortread annotations found for URI46
# setting up blast commands for URI46
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI46.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI46_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI46_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI46.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI46_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI46_pf32.xml
# No shortread annotations found for URI48
# setting up blast commands for URI48
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI48.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI48_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI48_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI48.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI48_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI48_pf32.xml
# No shortread annotations found for URI111
# setting up blast commands for URI111
# /home/mf019/longread_GWAS/longread_analysis/paired_assemblies/paired_only/longread/contigs
# Running blast command:
# blastn -query /tmp/URI111.fasta -task "blastn" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/plasmid_db/plasmid_db  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI111_whole_plasmid.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# whole plasmid blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/whole_plasmid/URI111_whole_plasmid.xml
# setting up blast command for pf32 blast
# Running blast command:
# blastx -query /tmp/URI111.fasta -task "blastx" -db /home/mf019/borrelia_plasmid_classifier_v3/dbs/pf32_db/pf32  -out /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI111_pf32.xml -evalue 1e-100 -num_threads 60 -outfmt 5 -max_target_seqs 5 -max_hsps 5
# pf32 blast results written to: /home/mf019/borrelia_plasmid_classifier_v3/output/blast_results/pf32/URI111_pf32.xml
# saddle up, we are done here!

# %% [markdown]
# ## ~~Ok so now let's strip out the pfam32s and blast those against the testor set from Ira!~~ will implement later after parsing

# %%
# let's define some possible annotated names!
#genbanks = glob.glob(f'{assembly_annotations}/*.gbff')

# %%
# lets make a dictionary containing our contigs, parse the genbank and pull the top level details for this.
# I forgot that I already did this below but this can hang around in case I need it (I probably will...)
#assembly_dict = {}
#for file in genbanks:
#    print(file.split('/')[-1])
#    sample_id = file.split("/")[-1].split(".")[0]
#    assembly_dict[sample_id] = {}
#    with open(file, "r") as f:
#        record = SeqIO.parse(f, "genbank")
#        for rec in record:
#            contig_id = rec.id
#            assembly_dict[sample_id]["contigs"] = {contig_id: {}}
#            contig_sequence = rec.seq
#            contig_len = len(rec.seq)
#            num_feats = len(rec.features)
#            assembly_dict[sample_id]["contigs"][contig_id] = {"contig_seq" : contig_sequence, "contig_len": contig_len, "feature_count": num_feats}

# %%
#pfam32_names = ["parA",'ParA','pf32','partition'] # this needs considerable WORK, # I may just blast one of the testors and see what possible names come back.
#parA_genes = {}
#for file in genbanks:
#    print(file)
#    sample_id = file.split("/")[-1].split(".")[0]
#    parA_genes[sample_id] = []
#    with open(file, "r") as f:
#        record = SeqIO.parse(f, "genbank")
#        for rec in record:
#            #print(rec.id)
#            for feature in rec.features:
#                if feature.type == "CDS":
#                    product = feature.qualifiers['product']
#                    if any(pfam32_names) in product[0]:
#                        feature.qualifiers['product']
#                        nucseq = feature.extract(rec.seq)
#                        if len(nucseq) % 3 != 0:
#                            print(f"Sequence length not divisible by 3 for {rec.id}---{sample_id}")
#                            nucseq += "N"
#                            print("adding N!")
#                        else:
#                            protseq = nucseq.translate(table=11, to_stop=True)
#                            gene = SeqIO.SeqRecord(protseq, id=f"{sample_id}-{rec.id}-ParA", name=product[0], description=f"{rec.id}---{sample_id}", dbxrefs=None)
#                            parA_genes[sample_id].append(gene)

# %%
## now write out to file for blastin!
#with open('parA_genes_query_v2.faa', 'w') as out:
#    for sample in parA_genes:
#        for gene in parA_genes[sample]:
#            print(gene)
#            SeqIO.write(gene, out, "fasta")

# %% [markdown]
# ## Let's parse our blast hits now!

# %%
pf32_results = glob.glob(f'{pf32_blast_results}/*.xml')
wp_results = glob.glob(f'{plasmid_blast_results}/*.xml')
mjf.logdebug(f'Found {len(pf32_results)} pf32 blast results')
mjf.logdebug(f'Found {len(wp_results)} whole plasmid blast results')

# %%
for result in pf32_results:
    print(result)
    name = Path(result).stem.split("_")[0]
    if name.endswith(('H','P')):
        print(f'input is longread: {name}')
        name = name[:-1:] # chop the char for dict lookup.
        current_asm = assembly_dict[name]['longread']
    else:
        print(f'input is shortread: {name}')
        current_asm = assembly_dict[name]['shortread']
    pf32_hits = parse_blast_results(result)
    for hit in pf32_hits:
        for k, v in enumerate(pf32_hits[hit]):
            curr_contig = current_asm[v["contig_id"]]
            curr_contig['pf32_hits'] = v

# %%
for result in wp_results:
    print(result)
    name = Path(result).stem.split("_")[0]
    if name.endswith(('H','P')):
        print(f'input is longread: {name}')
        name = name[:-1:] # chop the char for dict lookup.
        current_asm = assembly_dict[name]['longread']
    else:
        print(f'input is shortread: {name}')
        current_asm = assembly_dict[name]['shortread']
    wp_hits = parse_blast_results(result)
    for hit in wp_hits:
        for k, v in enumerate(wp_hits[hit]):
            curr_contig = current_asm[v["contig_id"]]
            curr_contig['wp_hits'] = v
            #print(f'Contig: {v["contig_id"]}')
            #print(f'Contig Length: {v["contig_len"]}')
            #print(f'Hit: {v["hit_title"]}')
            #print(f'Hit_Def: {v["hit_def"]}')
            #print(f'Expect: {v["hit_expect"]}')
            #print(f'Score: {v["hit_score"]}')
            #print(f'Query Start: {v["hit_query_start"]}')
            #print(f'Query End: {v["hit_query_end"]}')
            #print(f'Subject Start: {v["hit_subject_start"]}')
            #print(f'Subject End: {v["hit_subject_end"]}')
            #print(f'Identities: {v["hit_idents"]}')
            #print(f'Positives: {v["hit_pos"]}')
            #print(f'Gaps: {v["hit_gaps"]}')
            #print(f'Frame: {v["hit_frame"]}')
            #print(f'Query:   {v["hit_query"]}')
            #print(f'Subject: {v["hit_subject"]}')

# %%
pickle.dump(assembly_dict, open(f'{output_dir}/assembly_dict_v3_parsed.pkl', 'wb'))

# %%
for isolate in assembly_dict:
    for method in assembly_dict[isolate]:
        for contig in assembly_dict[isolate][method]:
            print(f'Isolate: {isolate}')
            print(f'Method: {method}')
            print(f'Contig: {assembly_dict[isolate][method][contig].items()}')
            print(f'pf32_hits: {[hit["contig_id"] for hit in assembly_dict[isolate][method][contig]["pf32_hits"]]}')
            print(f'wp_hits: {[hit["contig_id"] for hit in assembly_dict[isolate][method][contig]["wp_hits"]]}')
