# %%
import pandas
import pickle

# %%
# Ok let's crack open this jar of pickled plasmids.
parsing_table = pickle.load(open('parsing_tables/blast_parsing_dict.pkl', 'rb'))
# ok now let's set up the columns for our matrix and drop the synthetic vector I added a while back...
plasmids_in_db = {k : v for k, v in parsing_table.items()}
matrix_cols = []
for k in plasmids_in_db:
    matrix_cols.append(plasmids_in_db[k]['name'])
matrix_cols = list(set(matrix_cols))
matrix_cols.sort()
matrix_cols.remove('pBSV2')
matrix_cols.remove('lp21-cp9')
print(matrix_cols)
# Out:
# ['chromosome', 'cp26', 'cp32-1', 'cp32-1+5', 'cp32-10', 'cp32-11', 'cp32-12', 'cp32-2', 'cp32-3', 'cp32-3+10', 'cp32-4', 'cp32-5', 'cp32-5+1', 'cp32-5-1', 'cp32-6', 'cp32-7', 'cp32-8', 'cp32-9', 'cp32-9-4', 'cp9', 'cp9-3', 'lp17', 'lp21', 'lp25', 'lp28-1', 'lp28-11', 'lp28-2', 'lp28-3', 'lp28-4', 'lp28-5', 'lp28-6', 'lp28-7', 'lp28-8', 'lp28-9', 'lp36', 'lp38', 'lp5', 'lp54', 'lp56']

# %%
def make_method_dicts(subset):
    # Create a dictionary to store the sets
    sr_plasmids, lr_plasmids = {}, {}
    
    sr_subset = subset[subset['method'] == 'shortread']
    lr_subset = subset[subset['method'] == 'longread']
    
    # Group by the 'name' column and create sets of 'best_hit'
    for name, group in sr_subset.groupby('name'):
        best_hit_set = set(group['best_hit'])
        sr_plasmids[name] = best_hit_set
    
    # Group by the 'name' column and create sets of 'best_hit'
    for name, group in lr_subset.groupby('name'):
        best_hit_set = set(group['best_hit'])
        lr_plasmids[name] = best_hit_set
    
    print("lr_plasmids:", lr_plasmids)
    print(len(lr_plasmids.keys()))
    
    print("sr_plasmids:", sr_plasmids)
    print(len(sr_plasmids.keys()))
    return sr_plasmids, lr_plasmids

def generate_matrix(sr_plasmids, lr_plasmids, version, cutoff):
    for k in lr_plasmids:
        print(f'longread: {k} : len:{len(list(set(lr_plasmids[k])))} : {list(set(lr_plasmids[k]))}')
        lr_plasmids[k] = list(set(lr_plasmids[k]))
        print(f'shortread: {k[:-1]} : len: {len(list(set(sr_plasmids[k[:-1]])))}{list(set(sr_plasmids[k[:-1]]))}')
        sr_plasmids[k[:-1]] = list(set(sr_plasmids[k[:-1]]))
    
    dicts_of_results = [sr_plasmids, lr_plasmids]
    plasmid_presence_matrix = []
    for dict1 in dicts_of_results:
        for k in dict1:
            #print(k)
            for v in dict1[k]:
                #print(v)
                plasmid_presence_matrix.append((k,v))
    
    plasmid_df = pandas.DataFrame(plasmid_presence_matrix, columns=['key','val']).set_index(['key'])
    plasmid_count_matrix = plasmid_df.pivot_table(index='key', columns='val',aggfunc=len,fill_value=0,sort=True)
    plasmid_count_matrix['Sum'] = plasmid_count_matrix.sum(axis=1)
    print(plasmid_count_matrix)
    # make filename
    outfile = f'plasmid_presence_matrix_{version}_{cutoff}.csv'
    plasmid_count_matrix.to_csv(outfile)

# %%
new_csv = 'best_matches_v7_1000bp.tsv'
version = 'v7'
df_1000bp_cutoff = pandas.read_csv(new_csv,header=0,delimiter='\t')
df_2500bp_cutoff = df_1000bp_cutoff[df_1000bp_cutoff['contig_len'] >= 2500]
df_5000bp_cutoff = df_1000bp_cutoff[df_1000bp_cutoff['contig_len'] >= 5000]

# %%
subset1000 = df_1000bp_cutoff[['name','method','contig','best_hit','best_method','completeness']]
subset2500 = df_2500bp_cutoff[['name','method','contig','best_hit','best_method','completeness']]
subset5000 = df_5000bp_cutoff[['name','method','contig','best_hit','best_method','completeness']]

# %%
sr_pl_1000, lr_pl_1000 = make_method_dicts(subset1000)
sr_pl_2500, lr_pl_2500 = make_method_dicts(subset2500)
sr_pl_5000, lr_pl_5000 = make_method_dicts(subset5000)
# Out:
# lr_plasmids: {'ESI26H': {'cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp28-4', 'lp17', 'cp32-9', 'cp32-10', 'lp28-3', 'cp32-3', 'cp32-9-4', 'cp32-6', 'cp26', 'chromosome', 'lp28-9', nan}, 'UCT109H': {'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'cp32-10', 'cp32-3', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'lp28-1', 'cp32-6', 'cp26', 'chromosome', nan, 'lp38', 'lp25'}, 'UCT110H': {'lp54', 'chromosome', 'cp32-9', 'lp36', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UCT113H': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'lp21', 'lp17', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UCT29H': {'lp54', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'chromosome', 'lp38', nan}, 'UCT30H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'chromosome', 'lp38', nan}, 'UCT31H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'chromosome', nan}, 'UCT32H': {'lp54', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-5', 'lp17', 'cp32-8', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UCT35H': {'cp32-5', 'lp54', 'chromosome', 'lp28-4', 'lp17', 'cp32-12', 'lp5', 'cp32-3', 'cp32-10', 'cp32-13', 'cp32-4', 'cp32-7', 'cp9', 'cp26', 'lp28-1', 'lp38', nan}, 'UCT50H': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'cp32-10', 'cp32-7', 'cp32-4', 'cp32-11', 'cp32-13', 'cp9', 'cp26', 'chromosome', nan, 'lp38', 'lp25'}, 'UCT92H': {'lp54', 'lp36', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-1', 'cp32-5', 'lp17', 'cp32-8', 'cp32-4', 'cp26', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UCT96H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-3', 'lp28-2', 'cp32-1', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'chromosome', 'lp38', nan}, 'UNY149P': {'lp36', 'lp54', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UNY169P': {'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'cp32-12', 'lp28-4', 'cp32-10', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY172P': {'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'cp32-12', 'lp28-4', 'cp32-3', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY193P': {'lp36', 'lp54', 'lp28-3', 'lp28-6', 'cp32-6', 'lp28-7', 'lp5', 'cp32-10', 'cp32-13', 'lp28-2', 'lp17', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'chromosome', 'lp38'}, 'UNY203P': {'cp32-5', 'lp36', 'lp5', 'lp17', 'lp54', 'cp32-12', 'cp32-10', 'lp28-3', 'lp28-6', 'cp32-7', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'chromosome', 'lp38'}, 'UNY208P': {'cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-7', 'cp32-8', 'lp28-1', 'cp26', 'chromosome', 'lp25'}, 'URI101H': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'URI102H': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-10', 'cp32-3', 'lp28-2', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'cp32-2', 'lp25', 'lp56', 'cp32-7', 'lp28-1', 'lp38', nan}, 'URI103H': {'lp54', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32 ...
# 49
# sr_plasmids: {'ESI26': {'cp32-1', 'cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'cp32-12', 'cp32-10', 'lp28-3', 'cp32-8', 'lp28-2', 'lp28-7', 'cp26', 'chromosome', 'cp32-6', 'lp28-9', nan}, 'UCT109': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-10', 'lp28-2', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-7', 'lp28-1', 'lp38', nan}, 'UCT110': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UCT113': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-10', 'lp21', 'cp32-1', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'cp32-5-1', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UCT29': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-10', 'cp32-9-4', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9-3', 'cp9', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1', 'lp21-cp9', 'lp38', nan}, 'UCT30': {'lp54', 'chromosome', 'cp32-9', 'lp36', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp9-3', 'cp32-8', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp21-cp9', 'lp38', nan}, 'UCT31': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-10', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9-3', 'cp32-8', 'cp9', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1', nan}, 'UCT32': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-8', 'cp32-4', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UCT35': {'lp54', 'lp36', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'lp5', 'cp32-3', 'cp32-10', 'cp32-13', 'lp28-11', 'cp32-5', 'lp17', 'cp32-4', 'cp32-8', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1', 'lp38', nan}, 'UCT50': {'lp54', 'lp36', 'cp32-9', 'cp32-11', 'cp32-6', 'cp32-10', 'cp32-13', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'chromosome', 'lp38', nan}, 'UCT92': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'lp21', 'lp28-11', 'cp32-1', 'cp32-5', 'lp17', 'cp32-8', 'cp9-3', 'cp32-4', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp21-cp9', 'lp38', nan}, 'UCT96': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'lp5', 'cp32-3', 'lp28-2', 'cp32-1', 'lp17', 'cp32-8', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UNY149': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'cp32-4', 'cp32-8', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38', nan}, 'UNY169': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'chromosome', 'lp38', nan}, 'UNY172': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'chromosome', 'lp38', nan}, 'UNY193': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'lp28-7', 'cp32-6', 'lp5', 'lp28-8', 'cp32-3', 'cp32-10', 'cp32-13', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp9-3', 'cp32-8', 'cp9', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp21-cp9', 'lp38', nan}, 'UNY203': {'lp54', 'lp36', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'lp5', 'lp28-8', 'cp32-10',  ...
# 49
# lr_plasmids: {'ESI26H': {'cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp28-4', 'lp17', 'cp32-9', 'cp32-10', 'lp28-3', 'cp32-6', 'cp26', 'chromosome', 'lp28-9'}, 'UCT109H': {'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'cp32-10', 'cp32-3', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'lp28-1', 'cp32-6', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT110H': {'lp54', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UCT113H': {'lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-6', 'cp32-7', 'cp32-4', 'cp32-11', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT29H': {'lp54', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'chromosome', 'lp38'}, 'UCT30H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'chromosome', 'lp38'}, 'UCT31H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'chromosome'}, 'UCT32H': {'lp54', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-5', 'lp17', 'cp32-8', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UCT35H': {'cp32-5', 'lp54', 'chromosome', 'lp28-4', 'lp17', 'cp32-12', 'lp5', 'cp32-3', 'cp32-10', 'cp32-13', 'cp32-4', 'cp9', 'cp26', 'lp28-1', 'lp38'}, 'UCT50H': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'cp32-10', 'cp32-7', 'cp32-4', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT92H': {'lp54', 'lp36', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-1', 'cp32-5', 'lp17', 'cp32-8', 'cp32-4', 'cp26', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UCT96H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-3', 'lp28-2', 'cp32-1', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'chromosome', 'lp38'}, 'UNY149P': {'lp36', 'lp54', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UNY169P': {'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'cp32-12', 'lp28-4', 'cp32-10', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY172P': {'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'cp32-12', 'lp28-4', 'cp32-3', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY193P': {'lp36', 'lp54', 'lp28-3', 'lp28-6', 'cp32-6', 'lp28-7', 'lp5', 'cp32-10', 'cp32-13', 'lp28-2', 'lp17', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'chromosome', 'lp38'}, 'UNY203P': {'cp32-5', 'lp36', 'lp5', 'lp17', 'lp54', 'cp32-12', 'cp32-10', 'lp28-3', 'lp28-6', 'cp32-7', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'chromosome', 'lp38'}, 'UNY208P': {'cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-7', 'cp32-8', 'lp28-1', 'cp26', 'chromosome', 'lp25'}, 'URI101H': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'URI102H': {'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp56', 'cp32-10', 'cp32-3', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI103H': {'cp32-5', 'lp54', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'lp28-3', 'cp32-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-7', 'lp28-1', 'cp32-6', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI107H': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-1 ...
# 49
# sr_plasmids: {'ESI26': {'cp32-1', 'cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'cp32-12', 'cp32-10', 'lp28-3', 'cp32-8', 'lp28-2', 'lp28-7', 'cp26', 'chromosome', 'cp32-6', 'lp28-9'}, 'UCT109': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-7', 'lp28-1', 'lp38'}, 'UCT110': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-5', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UCT113': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-1', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UCT29': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'lp21', 'cp32-1', 'lp17', 'cp32-4', 'cp9-3', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1', 'lp38'}, 'UCT30': {'lp54', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'lp17', 'cp9-3', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp21-cp9', 'lp38'}, 'UCT31': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9-3', 'cp32-8', 'cp9', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1'}, 'UCT32': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-8', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UCT35': {'lp54', 'lp36', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'lp5', 'cp32-3', 'cp32-10', 'lp28-11', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1', 'lp38'}, 'UCT50': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'cp32-10', 'cp32-11', 'cp32-4', 'cp32-7', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT92': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'lp21', 'lp28-11', 'cp32-5', 'lp17', 'cp32-8', 'cp9-3', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'lp28-5', 'lp28-1', 'lp21-cp9', 'lp38'}, 'UCT96': {'cp32-1', 'lp54', 'lp36', 'lp17', 'lp28-4', 'cp32-9', 'lp28-3', 'cp32-8', 'lp28-2', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY149': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'cp32-4', 'cp32-8', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UNY169': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'lp28-3', 'cp32-10', 'cp32-7', 'cp32-4', 'lp28-2', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY172': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'lp28-3', 'cp32-3', 'cp32-7', 'cp32-4', 'cp32-8', 'lp28-2', 'cp32-6', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY193': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'lp28-7', 'cp32-6', 'lp28-8', 'cp32-3', 'cp32-13', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp9-3', 'cp9', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UNY203': {'lp54', 'lp36', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'lp5', 'lp28-8', 'cp32-10', 'cp32-3', 'cp32-13', 'lp28-11', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1', 'lp38'}, 'UNY208': {'cp32-1', 'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp28-3', 'cp32-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-7', 'cp32-8', 'lp28-1', 'cp26', 'chromosome', 'lp25'}, 'URI101': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-3', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp9-3', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'c ...
# 49
# lr_plasmids: {'ESI26H': {'cp32-1', 'cp32-5', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'cp32-10', 'lp28-3', 'cp32-6', 'cp26', 'chromosome', 'lp28-9'}, 'UCT109H': {'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'cp32-10', 'cp32-3', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'lp28-1', 'cp32-6', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT110H': {'lp54', 'lp28-4', 'lp17', 'cp32-9', 'cp32-12', 'lp28-3', 'cp32-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-7', 'lp28-5', 'lp28-1', 'cp32-6', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT113H': {'lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-6', 'cp32-7', 'cp32-4', 'cp32-11', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT29H': {'lp54', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'chromosome', 'lp38'}, 'UCT30H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'chromosome', 'lp38'}, 'UCT31H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-1', 'cp32-5', 'lp17', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'chromosome'}, 'UCT32H': {'lp54', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-5', 'lp17', 'cp32-8', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UCT35H': {'cp32-5', 'lp54', 'chromosome', 'lp28-4', 'lp17', 'cp32-12', 'lp5', 'cp32-3', 'cp32-10', 'cp32-13', 'cp32-4', 'cp9', 'cp26', 'lp28-1', 'lp38'}, 'UCT50H': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'cp32-10', 'cp32-7', 'cp32-4', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT92H': {'lp54', 'lp36', 'chromosome', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-1', 'cp32-5', 'lp17', 'cp32-8', 'cp32-4', 'cp26', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UCT96H': {'lp54', 'lp36', 'cp32-9', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp32-3', 'lp28-2', 'cp32-1', 'lp17', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'chromosome', 'lp38'}, 'UNY149P': {'lp36', 'lp54', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp32-3', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'UNY169P': {'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'cp32-12', 'lp28-4', 'cp32-10', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY172P': {'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'cp32-12', 'lp28-4', 'cp32-3', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY193P': {'lp36', 'lp54', 'lp28-3', 'lp28-6', 'cp32-6', 'lp28-7', 'lp5', 'cp32-10', 'cp32-13', 'lp28-2', 'lp17', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'chromosome', 'lp38'}, 'UNY203P': {'cp32-5', 'lp36', 'lp5', 'lp17', 'lp54', 'cp32-12', 'cp32-10', 'lp28-3', 'lp28-6', 'cp32-7', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'chromosome', 'lp38'}, 'UNY208P': {'cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-7', 'cp32-8', 'lp28-1', 'cp26', 'chromosome', 'lp25'}, 'URI101H': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38'}, 'URI102H': {'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'cp32-10', 'cp32-3', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI103H': {'cp32-5', 'lp54', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'lp28-3', 'cp32-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-7', 'lp28-1', 'cp32-6', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI107H': {'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-6', 'cp32-10', 'cp32-3', 'lp28-2', ...
# 49
# sr_plasmids: {'ESI26': {'cp32-1', 'lp54', 'lp36', 'lp17', 'cp32-9', 'cp32-12', 'cp32-10', 'lp28-3', 'cp32-8', 'lp28-2', 'lp28-7', 'cp26', 'chromosome', 'lp28-9'}, 'UCT109': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'cp32-9', 'lp28-3', 'cp32-4', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT110': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'cp32-2', 'lp38', 'lp25'}, 'UCT113': {'cp32-1', 'lp54', 'lp36', 'lp28-4', 'lp17', 'lp28-3', 'cp32-3', 'lp28-6', 'cp32-4', 'lp28-5', 'lp28-1', 'cp32-6', 'cp26', 'chromosome', 'lp21', 'lp38', 'lp25'}, 'UCT29': {'cp32-1', 'lp54', 'lp36', 'lp17', 'lp28-4', 'lp56', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-7', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp21', 'lp38', 'lp25'}, 'UCT30': {'lp54', 'lp28-4', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'cp32-2', 'lp21', 'lp21-cp9', 'lp38', 'lp25'}, 'UCT31': {'cp32-1', 'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'cp32-9', 'lp28-3', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp21', 'lp25'}, 'UCT32': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'cp32-2', 'lp38', 'lp25'}, 'UCT35': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp5', 'lp28-3', 'cp32-3', 'lp28-11', 'lp28-1', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT50': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'cp32-10', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UCT92': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-11', 'cp32-8', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp21-cp9', 'lp38', 'lp25'}, 'UCT96': {'lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-2', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY149': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'cp32-9', 'cp32-12', 'lp28-3', 'lp28-6', 'cp32-4', 'cp32-8', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'cp32-2', 'lp21', 'lp38', 'lp25'}, 'UNY169': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp28-3', 'cp32-10', 'cp32-4', 'lp28-2', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY172': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp28-3', 'lp28-2', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY193': {'lp54', 'lp36', 'lp28-4', 'lp56', 'cp32-12', 'lp28-3', 'lp28-6', 'lp28-2', 'lp28-1', 'lp28-7', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'UNY203': {'lp54', 'lp36', 'lp28-8', 'lp17', 'cp32-12', 'lp5', 'lp28-3', 'lp28-6', 'cp32-13', 'lp28-11', 'lp28-1', 'cp9', 'chromosome', 'lp38', 'lp25'}, 'UNY208': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp28-3', 'lp28-6', 'lp28-1', 'cp26', 'chromosome', 'lp25'}, 'URI101': {'cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-4', 'lp56', 'lp28-3', 'cp32-4', 'cp9-3', 'lp28-2', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp21', 'lp38', 'lp25'}, 'URI102': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'cp32-4', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI103': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'cp32-2', 'lp38', 'lp25'}, 'URI107': {'cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'cp32-4', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI111': {'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'cp32-7', 'cp9-3', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp21', 'lp38', 'lp25'}, 'URI112': {'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'cp32-12', 'lp28-3', 'lp28-6', 'cp9-3', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI117': {'lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI118': {'lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp25'}, 'URI120': {'lp54', 'lp56', 'lp17', 'lp28-4', 'lp36', 'lp28-3', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25'}, 'URI33': {'lp54', 'lp36', 'lp28-4', 'lp17', 'lp38', 'lp28-8', 'lp28-3', 'cp32-11 ...
# 49

# %%
generate_matrix(sr_pl_1000, lr_pl_1000, version, '1000bp')
generate_matrix(sr_pl_2500, lr_pl_2500, version, '2500bp')
generate_matrix(sr_pl_5000, lr_pl_5000, version, '5000bp')
# Out:
# longread: ESI26H : len:16 : ['cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'cp32-9', 'lp28-3', 'cp32-6', 'cp26', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-9-4', 'chromosome', 'lp28-9', nan]
# shortread: ESI26 : len: 17['cp32-1', 'cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'lp28-3', 'cp32-8', 'lp28-7', 'cp26', 'cp32-6', 'cp32-12', 'cp32-10', 'lp28-2', 'chromosome', 'lp28-9', nan]
# longread: UCT109H : len:18 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp38', nan]
# shortread: UCT109 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# longread: UCT110H : len:23 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# shortread: UCT110 : len: 24['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: UCT113H : len:19 : ['lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# shortread: UCT113 : len: 25['cp32-1', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-5-1', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: UCT29H : len:22 : ['cp32-1', 'cp32-5', 'lp54', 'chromosome', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21', 'lp38', nan]
# shortread: UCT29 : len: 29['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'cp32-9-4', 'lp28-2', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# longread: UCT30H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# shortread: UCT30 : len: 26['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# longread: UCT31H : len:22 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21', nan]
# shortread: UCT31 : len: 27['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', nan]
# longread: UCT32H : len:21 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38', nan]
# shortread: UCT32 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: UCT35H : len:17 : ['cp32-5', 'lp54', 'lp17', 'cp32-4', 'lp28-1', 'cp9', 'cp26', 'lp5', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-13', 'cp32-7', 'chromosome', 'lp38', nan]
# shortread: UCT35 : len: 24['cp32-5', 'lp54', 'lp36', 'lp17', 'lp38', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp5', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-13', 'cp32-7', 'chromosome', 'lp28-11', nan]
# longread: UCT50H : len:18 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'cp32-11', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-7', 'cp32-13', 'chromosome', 'lp38', nan]
# shortread: UCT50 : len: 19['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'cp32-11', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'chromosome', 'lp38', nan]
# longread: UCT92H : len:22 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38', nan]
# shortread: UCT92 : len: 29['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp38', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp21-cp9', 'lp28-11', nan]
# longread: UCT96H : len:21 : ['cp32-1', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'lp28-1', 'lp38', nan]
# shortread: UCT96 : len: 23['cp32-1', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp5', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38', nan]
# longread: UNY149P : len:19 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# shortread: UNY149 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: UNY169P : len:17 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY169 : len: 21['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# longread: UNY172P : len:16 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY172 : len: 21['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# longread: UNY193P : len:19 : ['lp36', 'lp54', 'lp17', 'lp28-3', 'lp28-6', 'cp9', 'cp32-6', 'lp28-7', 'cp26', 'lp5', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY193 : len: 34['lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'lp28-7', 'cp32-6', 'lp5', 'lp28-8', 'cp32-3', 'cp32-10', 'cp32-13', 'lp28-2', 'lp21', 'cp32-5', 'lp17', 'cp32-4', 'cp9-3', 'cp32-8', 'cp9', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'lp28-1', 'lp21-cp9', 'lp38', nan]
# longread: UNY203P : len:17 : ['cp32-5', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp5', 'cp32-12', 'cp32-10', 'cp32-7', 'lp28-1', 'lp38']
# shortread: UNY203 : len: 27['cp32-5', 'lp54', 'lp36', 'lp17', 'lp38', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp5', 'lp25', 'lp28-8', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-3', 'cp32-13', 'cp32-7', 'lp28-5', 'cp32-1+5', 'chromosome', 'lp28-11', nan]
# longread: UNY208P : len:18 : ['cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-1']
# shortread: UNY208 : len: 21['cp32-1', 'cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'cp32-9-4', 'chromosome', nan]
# longread: URI101H : len:23 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI101 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI102H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'lp28-1', 'cp26', 'cp32-2', 'lp25', 'lp56', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# shortread: URI102 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# longread: URI103H : len:19 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp38', nan]
# shortread: URI103 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI107H : len:20 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# shortread: URI107 : len: 22['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# longread: URI111H : len:22 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# shortread: URI111 : len: 27['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# longread: URI112H : len:21 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI112 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI117H : len:22 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI117 : len: 24['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# longread: URI118H : len:20 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', nan]
# shortread: URI118 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp21-cp9', nan]
# longread: URI120H : len:25 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI120 : len: 27['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# longread: URI33H : len:18 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-6', 'lp28-7', 'cp26', 'lp25', 'lp28-8', 'lp28-4', 'cp32-10', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI33 : len: 26['cp32-5', 'lp54', 'lp36', 'lp17', 'lp38', 'lp28-3', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-4', 'lp28-7', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-8', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-7', 'cp32-9-4', 'lp28-2', 'chromosome', 'lp21', 'lp28-11', nan]
# longread: URI34H : len:22 : ['lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp9', 'lp28-7', 'cp32-6', 'cp26', 'cp32-2', 'lp5', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38', nan]
# shortread: URI34 : len: 26['lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-4', 'cp32-8', 'cp9', 'lp28-7', 'cp32-6', 'cp26', 'cp32-2', 'lp5', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38', nan]
# longread: URI36H : len:23 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI36 : len: 24['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# longread: URI39H : len:24 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# shortread: URI39 : len: 27['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI40H : len:25 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-10', 'cp32-7', 'cp32-9-4', 'lp28-2', 'lp28-1', 'lp38', nan]
# shortread: URI40 : len: 27['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# longread: URI41H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', nan]
# shortread: URI41 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', nan]
# longread: URI42H : len:22 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'cp32-10', 'cp32-3', 'cp32-7', 'cp32-9-4', 'lp28-2', 'lp28-1', nan]
# shortread: URI42 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', nan]
# longread: URI44H : len:22 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38', nan]
# shortread: URI44 : len: 24['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI46H : len:22 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI46 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI47H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp38', nan]
# shortread: URI47 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI48H : len:17 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-6', 'lp28-7', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'chromosome', 'lp38', nan]
# shortread: URI48 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-4', 'lp28-7', 'cp32-6', 'cp26', 'lp25', 'lp28-8', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38', nan]
# longread: URI56H : len:20 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-6', 'cp26', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# shortread: URI56 : len: 23['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# longread: URI86H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'chromosome', 'lp38', nan]
# shortread: URI86 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI87H : len:22 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# shortread: URI87 : len: 24['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp38', nan]
# longread: URI88H : len:22 : ['cp32-1', 'cp32-5', 'lp54', 'lp17', 'lp38', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'lp28-7', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp28-11', nan]
# shortread: URI88 : len: 25['cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'lp38', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'lp28-7', 'cp32-6', 'cp26', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp21-cp9', 'lp28-11', nan]
# longread: URI89H : len:24 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp21-cp9', 'lp38', nan]
# shortread: URI89 : len: 27['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI91H : len:24 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI91 : len: 27['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI93H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'lp28-1', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38', nan]
# shortread: URI93 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'lp28-1', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38', nan]
# longread: UWI247P : len:17 : ['cp32-1', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38']
# shortread: UWI247 : len: 22['cp32-1', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-5', 'chromosome', 'lp38', nan]
# longread: UWI248P : len:18 : ['cp32-1', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38']
# shortread: UWI248 : len: 21['cp32-1', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'cp32-1+5', 'chromosome', 'lp38', nan]
# longread: UWI263P : len:19 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'lp28-5', 'chromosome', 'lp38']
# shortread: UWI263 : len: 26['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'cp32-2', 'cp32-5-1', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38', nan]
# longread: UWI283P : len:16 : ['cp32-1', 'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-2', 'lp28-5', 'chromosome']
# shortread: UWI283 : len: 23['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'cp32-1+5', 'chromosome', nan]
# val      chromosome  cp26  cp32-1  cp32-1+5  cp32-10  cp32-11  cp32-12  \
# key
# ESI26             1     1       1         0        1        0        1
# ESI26H            1     1       1         0        1        0        0
# UCT109            1     1       0         0        1        1        0
# UCT109H           1     1       0         0        1        0        0
# UCT110            1     1       0         0        0        1        1
# ...             ...   ...     ...       ...      ...      ...      ...
# UWI248P           1     1       1         0        0        1        1
# UWI263            1     1       1         0        1        1        1
# UWI263P           1     1       0         0        1        1        0
# UWI283            1     1       1         1        0        1        1
# UWI283P           1     1       1         0        0        0        1
#
# val      cp32-13  cp32-2  cp32-3  ...  lp28-6  lp28-7  lp28-8  lp28-9  lp36  \
# key                               ...
# ESI26          0       0       0  ...       0       1       0       1     1
# ESI26H         0       0       1  ...       0       0       0       1     1
# UCT109         0       1       1  ...       0       0       0       0     1
# UCT109H        0       0       1  ...       0       0       0       0     1
# UCT110         0       1       1  ...       1       0       0       0     1
# ...          ...     ...     ...  ...     ...     ...     ...     ...   ...
# UWI248P        0       0       1  ...       0       0       0       0     1
# UWI263         0       1       1  ...       0       0       0       0     1
# UWI263P        0       0       1  ...       0       0       0       0     1
# UWI283         0       0       1  ...       1       0       0       0     1
# UWI283P        0       0       1  ...       0       0       0       0     1
#
# val      lp38  lp5  lp54  lp56  Sum
# key
# ESI26       0    0     1     0   16
# ESI26H      0    0     1     0   15
# UCT109      1    0     1     1   22
# UCT109H     1    0     1     0   17
# UCT110      1    0     1     0   23
# ...       ...  ...   ...   ...  ...
# UWI248P     1    0     1     0   18
# UWI263      1    0     1     0   25
# UWI263P     1    0     1     0   19
# UWI283      0    0     1     1   22
# UWI283P     0    0     1     0   16
#
# [98 rows x 40 columns]
# longread: ESI26H : len:13 : ['cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp28-4', 'lp17', 'cp32-9', 'cp32-10', 'lp28-3', 'cp32-6', 'cp26', 'chromosome', 'lp28-9']
# shortread: ESI26 : len: 16['cp32-1', 'cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'lp28-3', 'cp32-8', 'lp28-7', 'cp26', 'cp32-6', 'cp32-12', 'cp32-10', 'lp28-2', 'chromosome', 'lp28-9']
# longread: UCT109H : len:17 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp38']
# shortread: UCT109 : len: 20['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# longread: UCT110H : len:21 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# shortread: UCT110 : len: 21['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# longread: UCT113H : len:15 : ['lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-6', 'cp32-7', 'cp32-4', 'cp32-11', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# shortread: UCT113 : len: 21['cp32-1', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: UCT29H : len:21 : ['cp32-1', 'cp32-5', 'lp54', 'chromosome', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21', 'lp38']
# shortread: UCT29 : len: 22['cp32-1', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# longread: UCT30H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# shortread: UCT30 : len: 22['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp21-cp9', 'lp38']
# longread: UCT31H : len:21 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21']
# shortread: UCT31 : len: 25['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21']
# longread: UCT32H : len:20 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# shortread: UCT32 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: UCT35H : len:15 : ['cp32-5', 'lp54', 'chromosome', 'lp28-4', 'lp17', 'cp32-12', 'lp5', 'cp32-3', 'cp32-10', 'cp32-13', 'cp32-4', 'cp9', 'cp26', 'lp28-1', 'lp38']
# shortread: UCT35 : len: 21['cp32-5', 'lp54', 'lp36', 'lp17', 'lp38', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp5', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'chromosome', 'lp28-11']
# longread: UCT50H : len:15 : ['cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'cp32-9', 'cp32-10', 'cp32-7', 'cp32-4', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25']
# shortread: UCT50 : len: 16['cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'cp32-11', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-7', 'chromosome', 'lp38']
# longread: UCT92H : len:21 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# shortread: UCT92 : len: 25['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp38', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp21-cp9', 'lp28-11']
# longread: UCT96H : len:20 : ['cp32-1', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'lp28-1', 'lp38']
# shortread: UCT96 : len: 15['cp32-1', 'lp54', 'lp36', 'lp17', 'lp28-4', 'cp32-9', 'lp28-3', 'cp32-8', 'lp28-2', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: UNY149P : len:19 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# shortread: UNY149 : len: 22['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: UNY169P : len:17 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY169 : len: 17['cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'lp28-3', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# longread: UNY172P : len:16 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY172 : len: 18['cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'lp28-3', 'cp32-4', 'cp32-8', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# longread: UNY193P : len:19 : ['lp36', 'lp54', 'lp17', 'lp28-3', 'lp28-6', 'cp9', 'cp32-6', 'lp28-7', 'cp26', 'lp5', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY193 : len: 27['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-4', 'cp9-3', 'lp28-1', 'cp9', 'lp28-7', 'cp32-6', 'cp26', 'lp25', 'lp28-8', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-13', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: UNY203P : len:17 : ['cp32-5', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp5', 'cp32-12', 'cp32-10', 'cp32-7', 'lp28-1', 'lp38']
# shortread: UNY203 : len: 24['cp32-5', 'lp54', 'lp36', 'lp17', 'lp38', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp5', 'lp25', 'lp28-8', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-3', 'cp32-13', 'cp32-7', 'chromosome', 'lp28-11']
# longread: UNY208P : len:18 : ['cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-1']
# shortread: UNY208 : len: 18['cp32-1', 'cp32-5', 'lp54', 'lp36', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-1']
# longread: URI101H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# shortread: URI101 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: URI102H : len:17 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp56', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp38']
# shortread: URI102 : len: 19['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# longread: URI103H : len:18 : ['cp32-5', 'lp54', 'chromosome', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-1', 'lp38']
# shortread: URI103 : len: 21['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: URI107H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: URI107 : len: 20['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# longread: URI111H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI111 : len: 21['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp9-3', 'lp28-1', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# longread: URI112H : len:20 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# shortread: URI112 : len: 22['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: URI117H : len:20 : ['lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# shortread: URI117 : len: 16['cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'lp28-5', 'lp28-1', 'lp21-cp9', 'lp38']
# longread: URI118H : len:18 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1']
# shortread: URI118 : len: 14['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-4', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp32-6', 'cp26', 'chromosome', 'lp25']
# longread: URI120H : len:23 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI120 : len: 15['lp54', 'lp56', 'lp17', 'lp28-4', 'lp36', 'lp28-3', 'cp32-4', 'cp9-3', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp21-cp9', 'lp38', 'lp25']
# longread: URI33H : len:17 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-6', 'lp28-7', 'cp26', 'lp25', 'lp28-8', 'lp28-4', 'cp32-10', 'chromosome', 'lp21', 'lp38']
# shortread: URI33 : len: 22['cp32-5', 'lp54', 'lp36', 'lp17', 'lp38', 'lp28-3', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-4', 'lp28-7', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-8', 'lp28-4', 'cp32-12', 'cp32-7', 'chromosome', 'lp21', 'lp28-11']
# longread: URI34H : len:19 : ['lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp9', 'lp28-7', 'cp32-6', 'cp26', 'lp5', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38']
# shortread: URI34 : len: 23['lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-4', 'cp32-8', 'cp9', 'lp28-7', 'cp32-6', 'cp26', 'cp32-2', 'lp5', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38']
# longread: URI36H : len:21 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp38']
# shortread: URI36 : len: 20['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: URI39H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI39 : len: 22['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# longread: URI40H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'lp28-1', 'lp38']
# shortread: URI40 : len: 24['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp21-cp9', 'lp38']
# longread: URI41H : len:17 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21']
# shortread: URI41 : len: 21['lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'lp28-1', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21']
# longread: URI42H : len:18 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome']
# shortread: URI42 : len: 19['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome']
# longread: URI44H : len:20 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# shortread: URI44 : len: 20['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-3', 'lp28-5', 'chromosome', 'lp21', 'lp38', nan]
# longread: URI46H : len:19 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp38']
# shortread: URI46 : len: 21['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: URI47H : len:19 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp38']
# shortread: URI47 : len: 23['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: URI48H : len:16 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-6', 'lp28-7', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'chromosome', 'lp38']
# shortread: URI48 : len: 19['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-4', 'lp28-7', 'cp32-6', 'cp26', 'lp25', 'lp28-8', 'lp28-4', 'cp32-3', 'chromosome', 'lp38']
# longread: URI56H : len:17 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-8', 'cp9-3', 'cp32-6', 'cp26', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp38']
# shortread: URI56 : len: 19['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-8', 'cp9-3', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp38']
# longread: URI86H : len:17 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'chromosome', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1', 'lp38']
# shortread: URI86 : len: 19['lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# longread: URI87H : len:20 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: URI87 : len: 20['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# longread: URI88H : len:21 : ['cp32-1', 'cp32-5', 'lp54', 'lp17', 'lp38', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'lp28-7', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp28-11']
# shortread: URI88 : len: 23['cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'lp38', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'lp28-7', 'cp32-6', 'cp26', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'chromosome', 'lp21', 'lp21-cp9', 'lp28-11']
# longread: URI89H : len:22 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI89 : len: 22['cp32-1', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp9-3', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# longread: URI91H : len:22 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI91 : len: 23['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# longread: URI93H : len:17 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21', 'lp38']
# shortread: URI93 : len: 21['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'lp28-1', 'cp26', 'cp32-2', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# longread: UWI247P : len:17 : ['cp32-1', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38']
# shortread: UWI247 : len: 19['cp32-1', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# longread: UWI248P : len:18 : ['cp32-1', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38']
# shortread: UWI248 : len: 19['cp32-1', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# longread: UWI263P : len:19 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'lp28-5', 'chromosome', 'lp38']
# shortread: UWI263 : len: 21['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38']
# longread: UWI283P : len:16 : ['cp32-1', 'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-2', 'lp28-5', 'chromosome']
# shortread: UWI283 : len: 22['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', nan]
# val      chromosome  cp26  cp32-1  cp32-10  cp32-11  cp32-12  cp32-13  cp32-2  \
# key
# ESI26             1     1       1        1        0        1        0       0
# ESI26H            1     1       1        1        0        0        0       0
# UCT109            1     1       0        0        1        0        0       1
# UCT109H           1     1       0        1        0        0        0       0
# UCT110            1     1       0        0        1        0        0       1
# ...             ...   ...     ...      ...      ...      ...      ...     ...
# UWI248P           1     1       1        0        1        1        0       0
# ...
# shortread: UNY149 : len: 18['cp32-5', 'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-4', 'cp32-8', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'lp28-5', 'lp28-1', 'lp21', 'lp38']
# longread: UNY169P : len:17 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp9', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY169 : len: 15['cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp28-3', 'cp32-10', 'cp32-4', 'lp28-2', 'cp9', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: UNY172P : len:16 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY172 : len: 11['lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp28-3', 'lp28-2', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: UNY193P : len:19 : ['lp36', 'lp54', 'lp17', 'lp28-3', 'lp28-6', 'cp9', 'cp32-6', 'lp28-7', 'cp26', 'lp5', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: UNY193 : len: 14['lp54', 'lp36', 'lp28-4', 'lp56', 'cp32-12', 'lp28-3', 'lp28-6', 'lp28-2', 'lp28-1', 'lp28-7', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: UNY203P : len:17 : ['cp32-5', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-4', 'cp9', 'cp32-6', 'cp26', 'lp5', 'cp32-12', 'cp32-10', 'cp32-7', 'lp28-1', 'lp38']
# shortread: UNY203 : len: 15['lp54', 'lp36', 'lp28-8', 'lp17', 'cp32-12', 'lp5', 'lp28-3', 'lp28-6', 'cp32-13', 'lp28-11', 'lp28-1', 'cp9', 'chromosome', 'lp38', 'lp25']
# longread: UNY208P : len:18 : ['cp32-1', 'cp32-5', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-1']
# shortread: UNY208 : len: 11['lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp28-3', 'lp28-6', 'lp28-1', 'cp26', 'chromosome', 'lp25']
# longread: URI101H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# shortread: URI101 : len: 17['cp32-5', 'lp54', 'lp36', 'lp17', 'chromosome', 'lp28-3', 'cp32-4', 'cp9-3', 'cp26', 'lp25', 'lp56', 'lp28-4', 'lp28-2', 'lp28-5', 'lp28-1', 'lp21', 'lp38']
# longread: URI102H : len:16 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp38']
# shortread: URI102 : len: 14['cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'cp32-4', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: URI103H : len:18 : ['cp32-5', 'lp54', 'chromosome', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-1', 'lp38']
# shortread: URI103 : len: 14['lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'cp32-2', 'lp38', 'lp25']
# longread: URI107H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: URI107 : len: 14['cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'cp32-4', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: URI111H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI111 : len: 15['lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'cp32-7', 'cp9-3', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp21', 'lp38', 'lp25']
# longread: URI112H : len:19 : ['lp54', 'cp32-9', 'lp17', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp21', 'lp38']
# shortread: URI112 : len: 15['lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'cp32-12', 'lp28-3', 'lp28-6', 'cp9-3', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: URI117H : len:19 : ['lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# shortread: URI117 : len: 12['lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: URI118H : len:18 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1']
# shortread: URI118 : len: 11['lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp25']
# longread: URI120H : len:21 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-3', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI120 : len: 12['lp54', 'lp56', 'lp17', 'lp28-4', 'lp36', 'lp28-3', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: URI33H : len:16 : ['lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-6', 'lp28-7', 'cp26', 'lp25', 'lp28-8', 'lp28-4', 'cp32-10', 'chromosome', 'lp21', 'lp38']
# shortread: URI33 : len: 15['lp54', 'lp36', 'lp28-4', 'lp17', 'lp38', 'lp28-8', 'lp28-3', 'cp32-11', 'cp9-3', 'lp28-7', 'cp26', 'chromosome', 'lp21', 'lp28-11', 'lp25']
# longread: URI34H : len:18 : ['lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp9', 'lp28-7', 'cp26', 'cp32-6', 'lp28-4', 'cp32-12', 'cp32-10', 'cp32-13', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38']
# shortread: URI34 : len: 18['lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp9', 'lp28-7', 'cp26', 'cp32-2', 'lp5', 'lp28-4', 'cp32-12', 'cp32-13', 'cp32-7', 'lp28-2', 'lp28-5', 'chromosome', 'lp38']
# longread: URI36H : len:21 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp38']
# shortread: URI36 : len: 18['lp54', 'lp36', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1', 'lp21', 'lp38']
# longread: URI39H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI39 : len: 16['lp54', 'lp36', 'lp17', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-4', 'cp9-3', 'cp26', 'lp25', 'lp56', 'lp28-4', 'lp28-2', 'lp28-1', 'lp21', 'lp38']
# longread: URI40H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp9-3', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-10', 'cp32-7', 'lp28-2', 'lp28-1', 'lp38']
# shortread: URI40 : len: 14['lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'cp32-7', 'cp9-3', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: URI41H : len:17 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-10', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21']
# shortread: URI41 : len: 16['lp54', 'lp36', 'lp17', 'cp32-9', 'chromosome', 'lp28-3', 'cp9-3', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-2', 'lp28-1', 'lp21']
# longread: URI42H : len:18 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome']
# shortread: URI42 : len: 12['cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp25']
# longread: URI44H : len:19 : ['lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'chromosome', 'lp38']
# shortread: URI44 : len: 14['lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'cp32-2', 'lp38', 'lp25']
# longread: URI46H : len:19 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp38']
# shortread: URI46 : len: 16['lp54', 'lp36', 'lp17', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp9-3', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'lp28-5', 'lp28-1', 'lp21', 'lp38']
# longread: URI47H : len:19 : ['cp32-5', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp38']
# shortread: URI47 : len: 15['lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-9', 'lp28-3', 'lp28-6', 'lp28-5', 'lp28-1', 'cp9', 'cp26', 'chromosome', 'cp32-2', 'lp38', 'lp25']
# longread: URI48H : len:16 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp9-3', 'cp32-6', 'lp28-7', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'chromosome', 'lp38']
# shortread: URI48 : len: 14['cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp17', 'lp28-8', 'lp28-3', 'cp32-11', 'cp9-3', 'lp28-7', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: URI56H : len:14 : ['lp54', 'lp36', 'lp28-4', 'lp17', 'lp56', 'lp28-3', 'cp32-3', 'lp28-6', 'cp32-7', 'cp9-3', 'cp26', 'chromosome', 'lp21', 'lp38']
# shortread: URI56 : len: 17['cp32-5', 'lp54', 'lp36', 'lp17', 'chromosome', 'lp28-3', 'lp28-6', 'cp9-3', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-1', 'lp21', 'lp38']
# longread: URI86H : len:17 : ['cp32-5', 'lp54', 'lp36', 'lp17', 'cp32-9', 'chromosome', 'lp28-6', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-7', 'lp28-1', 'lp38']
# shortread: URI86 : len: 17['lp54', 'lp36', 'lp17', 'cp32-9', 'chromosome', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-6', 'cp26', 'cp32-2', 'lp25', 'lp28-4', 'cp32-12', 'lp28-5', 'lp28-1', 'lp38']
# longread: URI87H : len:19 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp38']
# shortread: URI87 : len: 15['cp32-5', 'lp54', 'lp36', 'lp28-4', 'lp56', 'lp17', 'lp28-3', 'cp32-7', 'cp32-4', 'lp28-2', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: URI88H : len:20 : ['cp32-1', 'cp32-5', 'lp54', 'lp17', 'lp28-3', 'lp28-6', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'lp28-7', 'cp32-6', 'cp26', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'chromosome', 'lp21', 'lp38']
# shortread: URI88 : len: 13['lp36', 'lp54', 'lp28-4', 'lp17', 'lp28-3', 'lp28-6', 'lp28-1', 'lp28-7', 'cp26', 'chromosome', 'lp21', 'lp21-cp9', 'lp38']
# longread: URI89H : len:21 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI89 : len: 16['lp54', 'lp36', 'lp17', 'chromosome', 'lp28-3', 'cp32-4', 'cp9-3', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-3', 'lp28-2', 'lp28-1', 'lp21', 'lp38']
# longread: URI91H : len:22 : ['cp32-1', 'cp32-5', 'lp54', 'lp36', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'cp32-4', 'lp28-1', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'chromosome', 'lp21', 'lp38']
# shortread: URI91 : len: 16['cp32-5', 'lp54', 'lp36', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp26', 'lp25', 'lp56', 'lp28-4', 'lp28-2', 'lp28-1', 'lp21', 'lp38']
# longread: URI93H : len:17 : ['cp32-5', 'lp54', 'lp36', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21', 'lp38']
# shortread: URI93 : len: 17['lp54', 'lp36', 'lp17', 'cp32-9', 'chromosome', 'lp28-3', 'cp32-4', 'cp9-3', 'cp26', 'lp25', 'lp56', 'lp28-4', 'cp32-7', 'lp28-2', 'lp28-1', 'lp21', 'lp38']
# longread: UWI247P : len:17 : ['cp32-1', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38']
# shortread: UWI247 : len: 12['lp54', 'lp36', 'lp17', 'lp28-4', 'lp28-3', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'cp32-2', 'lp38', 'lp25']
# longread: UWI248P : len:18 : ['cp32-1', 'lp36', 'lp54', 'lp17', 'chromosome', 'lp28-3', 'cp32-11', 'cp32-4', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'cp32-7', 'lp28-5', 'lp28-1', 'lp38']
# shortread: UWI248 : len: 11['lp54', 'lp36', 'lp28-4', 'lp17', 'lp28-3', 'lp28-5', 'lp28-1', 'cp26', 'chromosome', 'lp38', 'lp25']
# longread: UWI263P : len:19 : ['cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-11', 'cp32-8', 'lp28-1', 'cp9', 'cp32-6', 'cp26', 'lp25', 'lp28-4', 'cp32-10', 'cp32-3', 'lp28-5', 'chromosome', 'lp38']
# shortread: UWI263 : len: 10['lp54', 'lp36', 'lp17', 'lp28-3', 'lp28-5', 'lp28-1', 'cp9', 'chromosome', 'lp38', 'lp25']
# longread: UWI283P : len:16 : ['cp32-1', 'cp32-5', 'lp36', 'lp54', 'cp32-9', 'lp17', 'lp28-3', 'cp32-4', 'cp26', 'lp25', 'lp28-4', 'cp32-12', 'cp32-3', 'lp28-2', 'lp28-5', 'chromosome']
# shortread: UWI283 : len: 14['lp54', 'lp36', 'lp28-4', 'lp17', 'cp32-12', 'lp56', 'lp28-3', 'lp28-6', 'cp32-4', 'lp28-5', 'lp28-2', 'cp26', 'chromosome', 'lp25']
# val      chromosome  cp26  cp32-1  cp32-10  cp32-11  cp32-12  cp32-13  cp32-2  \
# key
# ESI26             1     1       1        1        0        1        0       0
# ESI26H            1     1       1        1        0        0        0       0
# UCT109            1     1       0        0        0        0        0       0
# UCT109H           1     1       0        1        0        0        0       0
# UCT110            1     1       0        0        0        0        0       1
# ...             ...   ...     ...      ...      ...      ...      ...     ...
# UWI248P           1     1       1        0        1        1        0       0
# UWI263            1     0       0        0        0        0        0       0
# UWI263P           1     1       0        1        1        0        0       0
# UWI283            1     1       0        0        0        1        0       0
# UWI283P           1     1       1        0        0        1        0       0
#
# val      cp32-3  cp32-4  ...  lp28-6  lp28-7  lp28-8  lp28-9  lp36  lp38  lp5  \
# key                      ...
# ESI26         0       0  ...       0       1       0       1     1     0    0
# ESI26H        0       0  ...       0       0       0       1     1     0    0
# UCT109        0       1  ...       0       0       0       0     1     1    0
# UCT109H       1       1  ...       0       0       0       0     1     1    0
# UCT110        0       0  ...       1       0       0       0     1     1    0
# ...         ...     ...  ...     ...     ...     ...     ...   ...   ...  ...
# UWI248P       1       1  ...       0       0       0       0     1     1    0
# UWI263        0       0  ...       0       0       0       0     1     1    0
# UWI263P       1       0  ...       0       0       0       0     1     1    0
# UWI283        0       1  ...       1       0       0       0     1     0    0
# UWI283P       1       1  ...       0       0       0       0     1     0    0
#
# val      lp54  lp56  Sum
# key
# ESI26       1     0   14
# ESI26H      0     0   12
# UCT109      1     1   15
# UCT109H     1     0   17
# UCT110      1     0   14
# ...       ...   ...  ...
# UWI248P     1     0   18
# UWI263      1     0   10
# UWI263P     1     0   19
# UWI283      1     1   14
# UWI283P     1     0   16
#
# [98 rows x 37 columns]

# %%
df_v6_1000bp_matrix = pandas.read_csv('plasmid_presence_matrix_v7_2500bp.csv')
lr_matrix = df_v6_1000bp_matrix[df_v6_1000bp_matrix['key'].str[-1].isin(['H', 'P'])]
sr_matrix = df_v6_1000bp_matrix[~df_v6_1000bp_matrix['key'].str[-1].isin(['H', 'P'])]

# %%
lr_matrix.to_csv('plasmid_presence_matrix_v7_2500bp_LR.csv', index=False)
sr_matrix.to_csv('plasmid_presence_matrix_v7_2500bp_SR.csv', index=False)
