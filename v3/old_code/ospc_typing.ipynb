# %%
import os
import glob
import pandas
import pprint
from Bio            import Entrez
from Bio            import SeqIO
from Bio.Blast      import NCBIXML

############################################
Entrez.email = "mfoster11@mgh.harvard.edu" # Always tell NCBI who you are
############################################

# %%
GET_REFERENCE_SEQS = False
FIX_REFERENCE_SEQS = True
WRITE_REF_SEQS = True
EXTRACT_GENES = True
BUILD_BLAST_DB = True
RUN_BLAST = True
PARSE_BLAST_RESULTS = True
WRITE_RESULTS = True
MERGE_RESULTS = True
FINALIZE_AND_WRITE_METADATA = True

# %%
def load_input_metadata(metadata : str) -> pandas.DataFrame:
    input_metadata = pandas.read_csv(metadata)
    return input_metadata

def parse_blast_results(blast_results : str) -> dict:
    file_size = os.path.getsize(blast_results)
    if file_size == 0:
        return None
    results = {}
    with open(blast_results, "r") as f:
        blast_records = NCBIXML.parse(f)
        for record in blast_records:
            results[record.query] = []
            for alignment in record.alignments:
                for hsp in alignment.hsps:
                    results[record.query].append((alignment.title, hsp.expect, hsp.score,))
    return results

# %%
assemblies = glob.glob("../../assemblies/*/annotation/*/*.gbff")
#print(assemblies)

metadata = "../metadata/longread_metadata_v2.csv"
input_metadata = load_input_metadata(metadata)
known_types = input_metadata[['Isolate', 'OspC_Type']]
#print(known_types)

# %% [markdown]
# ## Next Steps
# Ok, so now what we'll do is take the table above, pull all isolates that have a known ospc_type, then pull the ospc annotations from each isolate, then make a tree, then confirm tree layout with known types, then run tree of all known ospc annotations, then use previous labels as classifications for each cluster.

# %% [markdown]
# # Okay, Ira has sent me a large file of OspC types and AA seqs
# I will be taking this, making a blast DB and then I need to isolate the OspC seqs from each assembly, then blast against the OspC database.

# %%
ospc_genotype_to_ref = {
     'A' : 'X69596',
    'Ba' : 'EF537413',
    'Bb' : 'NC_011724',
     'C' : 'DQ437462',
    'Da' : 'AF029863',
    'Db' : 'GQ478283',
     'E' : 'AY275221',
    'Fa' : 'AY275225',
    'Fb' : 'EF537433',
    'Fc' : 'GQ478285',
     'G' : 'AY275223',
    'Ha' : 'EU377781',
    'Hb' : 'GQ478286',
    'Ia' : 'AY275219',
    'Ib' : 'EU377752',
     'J' : 'CP001535',
     'K' : 'AY275214',
     'L' : 'EU375832',
     'M' : 'CP001550',
     'N' : 'EU377775',
     'O' : 'FJ997281',
     'T' : 'AY275222',
    'Ua' : 'EU377769',
    'Ub' : 'GQ478287',
    'A3' : 'EF592541',
    'B3' : 'EF592542',
    'C3' : 'EF592543',
    'D3' : 'EF592544',
    'E3' : 'EF592545',
    'F3' : 'EF592547',
    'H3' : 'FJ932733',
    'I3' : 'FJ932734',
    'B.bissettii_25015' : 'U04282'
}
# okay so per Ira, these ATs correspond to OspC types. I should blast these ATs against the OspC types and see how they match up... (2024-03-05 - MJF)
ospc_AT_to_ref = {
   'AT1' : 'EU482041',
   'AT2' : 'EU482042',
   'AT3' : 'EU482043',
   'AT4' : 'EU482044',
   'AT5' : 'EU482045',
   'AT6' : 'EU482046',
   'AT7' : 'EU482047',
   'AT8' : 'EU482048',
   'AT9' : 'EU482049',
  'AT10' : 'EU482050',
  'AT11' : 'EU482051',
  'AT12' : 'EU482052',
  'AT13' : 'EU482053',
  'AT14' : 'EU482054',
  'AT15' : 'EU482055',
  'AT16' : 'EU482056',
}
len(ospc_genotype_to_ref)

# %%
if GET_REFERENCE_SEQS is True:
    # ok now to pull all of those seqs via entrez direct and then make a multifasta file upon which to build a blastdb from
    # we will use the following command to pull the sequences from the NCBI nucleotide database using our defined dictionary
    # and we will also call the command using the biopython wrapper for entrez direct
    for ospc_type, ref in ospc_genotype_to_ref.items():
        print(f"fetching record for {ospc_type} : {ref}")
        handle = Entrez.efetch(db="nucleotide", id=ref, rettype="fasta", retmode="text")
        record = handle.read()
        with open(f"ospc_seqs/{ospc_type}.fasta", "w") as f:
            print("writing record to file!")
            f.write(record[0::])
        handle.close()
    print("done!")
    for ospc_AT, ref in ospc_AT_to_ref.items():
        print(f"fetching record for {ospc_AT} : {ref}")
        handle = Entrez.efetch(db="nucleotide", id=ref, rettype="fasta", retmode="text")
        record = handle.read()
        with open(f"AT_seqs/{ospc_AT}.fasta", "w") as f:
            print("writing record to file!")
            f.write(record[0::])
        handle.close()
    print("done!")
else:
    print("skipping reference sequence retrieval")

# %%
if FIX_REFERENCE_SEQS is True:
    # ok so some of those entries include the entire plasmid sequence not just the ospc gene, so we will need to extract the ospc gene from the plasmid sequence
    # the ones that are plasmid sequences are as follows:
    # Bb, J, M,
    # we will need to extract the ospc gene from these sequences
    for ospc_type in ['Bb', 'J', 'M']:
        print(ospc_genotype_to_ref[ospc_type])

    coords = {
        'Bb' : (16904,17540), # DON'T FORGET TO CHANGE TO 0 BASED COORDINATES!
        'J' : (16909,17545), # DON'T FORGET TO CHANGE TO 0 BASED COORDINATES!
        'M' : (16916,17555), # DON'T FORGET TO CHANGE TO 0 BASED COORDINATES!
    }
    #
    ## ok we already have the full plasmid seqs for each of these three types, we also now have the coordinates
    for ospc_type in ['Bb', 'J', 'M']:
        print(f"extracting ospc gene from {ospc_type} sequence")
        with open(f"ospc_seqs/{ospc_type}.fasta", "r") as f:
            record = SeqIO.read(f, "fasta")
            print(record)
            ospc_gene = record[coords[ospc_type][0]:coords[ospc_type][1]]
            with open(f"ospc_seqs/{ospc_type}_ospc.fasta", "w") as f:
                SeqIO.write(ospc_gene, f, "fasta")
else:
    print("skipping ospc gene extraction and record repair")

# %%
if WRITE_REF_SEQS is True:
    # Now lets write out all of our OspC sequences to a single file for blastdb creation
    ospc_seqs = glob.glob("ospc_seqs/*.fasta")
    #print(ospc_seqs)
    ospc_seq_file = []
    for seq in ospc_seqs:
        record = SeqIO.read(seq, "fasta")
        record.id = "OspC_Type-" + seq.split("/")[-1].split(".")[0]
        record.description = ""
        #print(record.id)
        ospc_seq_file.append(record)
    with open("all_ospc.fasta", "w") as f:
        SeqIO.write(ospc_seq_file, f, "fasta")
    print("OspC file written!")
else:
    print("skipping writing out reference OspC sequences")

# %%
if WRITE_REF_SEQS is True:
    # Okay now lets write the AT sequences to a single file for blastdb creation
    AT_seqs = glob.glob("AT_seqs/*.fasta")
    #print(AT_seqs)
    AT_seq_file = []
    for seq in AT_seqs:
        record = SeqIO.read(seq, "fasta")
        record.id = "OspC_Type-" + seq.split("/")[-1].split(".")[0]
        record.description = ""
        #print(record.id)
        AT_seq_file.append(record)
    with open("all_ospc_ATs.fasta", "w") as f:
        SeqIO.write(AT_seq_file, f, "fasta")
    print("AT file written!")
else:
    print("skipping writing out reference AT sequences")

# %%
if BUILD_BLAST_DB is True:
    # ok now lets make a local blast DB for our OspC types
    from Bio.Blast.Applications import NcbimakeblastdbCommandline
    cmd = NcbimakeblastdbCommandline(input_file="all_ospc.fasta", dbtype="nucl", out="blastdb/ospc/ospc")
    print(cmd)
    stdout, stderr = cmd()
    print(stdout)
    print(stderr)
    # now lets make a local blast DB for our AT types
    from Bio.Blast.Applications import NcbimakeblastdbCommandline
    cmd = NcbimakeblastdbCommandline(input_file="all_ospc_ATs.fasta", dbtype="nucl", out="blastdb/ospcAT/ospcAT")
    print(cmd)
    stdout, stderr = cmd()
    print(stdout)
    print(stderr)
else:
    print("skipping making blastdb for AT")

# %%
# ok now lets pull all of the ospCs from all assemblies and then blast them against our local blastdb
ospc_identifiers = [
    #"S2/P23", # This may not be right. I need to figure out why some assemblies lack OspC.
    "P12", # this is what it's called in garinii per Matteo.
    "ospC",
    "OspC",
    "Ospc",
    "ospc",
    "outer surface protein C",
    "Outer surface protein C",
    "outer surface lipoprotein C",
    "Outer surface lipoprotein C",
    "outer surface protein c",
]
if EXTRACT_GENES is True:
    ospc_genes = {}
    for file in assemblies:
        #print(file)
        sample_id = file.split("/")[-1].split(".")[0].replace("_200","" )
        ospc_genes[sample_id] = []
        with open(file, "r") as f:
            record = SeqIO.parse(f, "genbank")
            for rec in record:
                #print(rec.id)
                for feature in rec.features:
                    if feature.type == "CDS":
                        product = feature.qualifiers['product']
                        if any(x in product[0] for x in ospc_identifiers):
                            #feature.qualifiers['product']
                            # get sequence
                            #print(feature.location)
                            # Now lets make a new SeqRecord object for the gene and append it to our list of OspC Genes!
                            seq = feature.extract(rec.seq)
                            gene = SeqIO.SeqRecord(seq, id=product[0], name=product[0], description=f"gene: {product[0]} from isolate {sample_id}", dbxrefs=None)
                            ospc_genes[sample_id].append(gene)
    # Okay now lets pull the ospC genes from all of the assemblies and write them to a file for blasting!
    for sample in ospc_genes:
        #print(sample)
        #print(ospc_genes[sample])
        with open(f"temp_in/{sample}.osps.fasta", "w") as f:
            SeqIO.write(ospc_genes[sample], f"temp_in/{sample}.osps.fasta", "fasta")
else:
    print("skipping gene extraction")

# %%
ospc_genes = glob.glob("temp_in/*.osps.fasta")
ospc_genes = [x.split("/")[-1].replace(".osps.fasta","") for x in ospc_genes]

# %%
if RUN_BLAST is True:
    # ok now we can blast each file against our local blastdb
    from Bio.Blast.Applications import NcbiblastnCommandline
    for sample in ospc_genes:
        print(f"blasting {sample}")
        cmd = NcbiblastnCommandline(query=f"temp_in/{sample}.osps.fasta", db="blastdb/ospc/ospc", out=f"temp_out/{sample}.osps_blast.xml", outfmt=5)
        print(cmd)
        stdout, stderr = cmd()
        print(stdout)
        print(stderr)
else:
    print("skipping blasting")

# %%
if RUN_BLAST is True:
    # ok now we can blast each file against our local blastdb
    from Bio.Blast.Applications import NcbiblastnCommandline
    for sample in ospc_genes:
        print(f"blasting {sample}")
        cmd = NcbiblastnCommandline(query=f"temp_in/{sample}.osps.fasta", db="blastdb/ospcAT/ospcAT", out=f"temp_out/{sample}.ospsAT_blast.xml", outfmt=5)
        print(cmd)
        stdout, stderr = cmd()
        print(stdout)
        print(stderr)
else:
    print("skipping blasting")

# %%
# ok now we can parse the blast results and then add the ospc type to the metadata
# we will use the function defined at the beginning to parse the blast results!

# %%
if PARSE_BLAST_RESULTS is True:
    checked_types_ospc = pandas.DataFrame(columns=["Isolate", "ospc_newtype"])
    blast_results_ospc = glob.glob("temp_out/*.osps_blast.xml")

    for result in blast_results_ospc:
        sample_id = result.split("/")[-1].split(".")[0].replace(".osps_blast", "")
        isolate = sample_id
        ospc_type = "unknown"
        parsed_results = parse_blast_results(result)
        if parsed_results is not None:
            for result in parsed_results:
                if len(parsed_results[result]) > 0:
                    best_hit = parsed_results[result][0][0]
                    coords = parsed_results[result][0][0].find("OspC_Type-")
                    ospc_type = parsed_results[result][0][0][coords+10:coords+14]
                    #print(isolate, ospc_type)
                    checked_types_ospc.loc[len(checked_types_ospc)] = [isolate, ospc_type]
                    break
        else:
            #print(isolate, ospc_type)
            checked_types_ospc.loc[len(checked_types_ospc)] = [isolate, "unknown"]
else:
    print("skipping parsing blast results")

# %%
if WRITE_RESULTS is True:
    checked_types_ospc.to_csv("new_ospC_types.csv", index=False)
else:
    print("skipping writing initial results")

# %%
if PARSE_BLAST_RESULTS is True:
    checked_types_AT = pandas.DataFrame(columns=["Isolate", "AT_type"])
    blast_results_AT = glob.glob("temp_out/*.ospsAT_blast.xml")
    print(blast_results_AT)
    for result in blast_results_AT:
        print(result)
        sample_id = result.split("/")[-1].replace(".ospsAT_blast.xml", "")
        isolate = sample_id
        parsed_results = parse_blast_results(result)
        if parsed_results is not None:
            for result in parsed_results:
                if len(parsed_results[result]) > 0:
                    best_hit = parsed_results[result][0][0]
                    coords = parsed_results[result][0][0].find("OspC_Type-")
                    ospc_type = parsed_results[result][0][0][coords+10:coords+14]
                    print(isolate, ospc_type)
                    checked_types_AT.loc[len(checked_types_AT)] = [isolate, ospc_type]
                    break
        else:
            print(isolate, ospc_type)
            checked_types_AT.loc[len(checked_types_AT)] = [isolate, "unknown"]
else:
    print("skipping parsing blast results")
# Out:
# ['temp_out/URI64.ospsAT_blast.xml', 'temp_out/UWI245.ospsAT_blast.xml', 'temp_out/K74.ospsAT_blast.xml', 'temp_out/ESI311.ospsAT_blast.xml', 'temp_out/URI105.ospsAT_blast.xml', 'temp_out/ESI295.ospsAT_blast.xml', 'temp_out/UWI220.ospsAT_blast.xml', 'temp_out/UNY143.ospsAT_blast.xml', 'temp_out/UMA11.ospsAT_blast.xml', 'temp_out/K11.ospsAT_blast.xml', 'temp_out/K30.ospsAT_blast.xml', 'temp_out/UCT66.ospsAT_blast.xml', 'temp_out/UCT110.ospsAT_blast.xml', 'temp_out/UNY184.ospsAT_blast.xml', 'temp_out/URI20.ospsAT_blast.xml', 'temp_out/UNY162.ospsAT_blast.xml', 'temp_out/UMA4.ospsAT_blast.xml', 'temp_out/5A18NP1-JBb08-E.ospsAT_blast.xml', 'temp_out/UNY203.ospsAT_blast.xml', 'temp_out/UWI282.ospsAT_blast.xml', 'temp_out/UWI264.ospsAT_blast.xml', 'temp_out/UNY139.ospsAT_blast.xml', 'temp_out/K7.ospsAT_blast.xml', 'temp_out/BL546.ospsAT_blast.xml', 'temp_out/UNY176.ospsAT_blast.xml', 'temp_out/UNY148.ospsAT_blast.xml', 'temp_out/URI34.ospsAT_blast.xml', 'temp_out/UNY190.ospsAT_blast.xml', 'temp_out/UCT104.ospsAT_blast.xml', 'temp_out/K24.ospsAT_blast.xml', 'temp_out/URI89.ospsAT_blast.xml', 'temp_out/UWI270.ospsAT_blast.xml', 'temp_out/UCT29.ospsAT_blast.xml', 'temp_out/UNY217.ospsAT_blast.xml', 'temp_out/URI111.ospsAT_blast.xml', 'temp_out/ESI305.ospsAT_blast.xml', 'temp_out/K60.ospsAT_blast.xml', 'temp_out/K86.ospsAT_blast.xml', 'temp_out/UNY208.ospsAT_blast.xml', 'temp_out/UNY132.ospsAT_blast.xml', 'temp_out/UWI251.ospsAT_blast.xml', 'temp_out/URI70.ospsAT_blast.xml', 'temp_out/UNY169.ospsAT_blast.xml', 'temp_out/UNY157.ospsAT_blast.xml', 'temp_out/UWI234.ospsAT_blast.xml', 'temp_out/L113.ospsAT_blast.xml', 'temp_out/MC105.ospsAT_blast.xml', 'temp_out/UNY136.ospsAT_blast.xml', 'temp_out/UWI255.ospsAT_blast.xml', 'temp_out/UCT32.ospsAT_blast.xml', 'temp_out/K64.ospsAT_blast.xml', 'temp_out/K82.ospsAT_blast.xml', 'temp_out/ESI301.ospsAT_blast.xml', 'temp_out/ESI285.ospsAT_blast.xml', 'temp_out/UNY153.ospsAT_blast.xml', 'temp_out/UWI230.ospsAT_blast.xml', 'temp_out/B418.ospsAT_blast.xml', 'temp_out/UCT121.ospsAT_blast.xml', 'temp_out/UCT69.ospsAT_blast.xml', 'temp_out/B500.ospsAT_blast.xml', 'temp_out/UCT76.ospsAT_blast.xml', 'temp_out/UNY172.ospsAT_blast.xml', 'temp_out/UNY194.ospsAT_blast.xml', 'temp_out/K3.ospsAT_blast.xml', 'temp_out/ESI320.ospsAT_blast.xml', 'temp_out/UNY213.ospsAT_blast.xml', 'temp_out/UNY129.ospsAT_blast.xml', 'temp_out/UWI274.ospsAT_blast.xml', 'temp_out/URI55.ospsAT_blast.xml', 'temp_out/B31-K2.ospsAT_blast.xml', 'temp_out/UNY180.ospsAT_blast.xml', 'temp_out/URI24.ospsAT_blast.xml', 'temp_out/UNY158.ospsAT_blast.xml', 'temp_out/UNY166.ospsAT_blast.xml', 'temp_out/UCT62.ospsAT_blast.xml', 'temp_out/URI41.ospsAT_blast.xml', 'temp_out/UWI260.ospsAT_blast.xml', 'temp_out/URI99.ospsAT_blast.xml', 'temp_out/UNY207.ospsAT_blast.xml', 'temp_out/K89.ospsAT_blast.xml', 'temp_out/5A18NP1-JBb08-A.ospsAT_blast.xml', 'temp_out/URI120.ospsAT_blast.xml', 'temp_out/ESI315.ospsAT_blast.xml', 'temp_out/URI101.ospsAT_blast.xml', 'temp_out/UNY218.ospsAT_blast.xml', 'temp_out/K70.ospsAT_blast.xml', 'temp_out/URI60.ospsAT_blast.xml', 'temp_out/UWI241.ospsAT_blast.xml', 'temp_out/URI86.ospsAT_blast.xml', 'temp_out/UMA15.ospsAT_blast.xml', 'temp_out/K15.ospsAT_blast.xml', 'temp_out/UWI224.ospsAT_blast.xml', 'temp_out/UNY147.ospsAT_blast.xml', 'temp_out/UNY179.ospsAT_blast.xml', 'temp_out/BL082_H1.ospsAT_blast.xml', 'temp_out/ESI291.ospsAT_blast.xml', 'temp_out/UNY202.ospsAT_blast.xml', 'temp_out/UNY138.ospsAT_blast.xml', 'temp_out/UWI265.ospsAT_blast.xml', 'temp_out/UWI283.ospsAT_blast.xml', 'temp_out/URI44.ospsAT_blast.xml', 'temp_out/5A18NP1-JBb08-D.ospsAT_blast.xml', 'temp_out/MR616.ospsAT_blast.xml', 'temp_out/UMA5.ospsAT_blast.xml', 'temp_out/UNY163.ospsAT_blast.xml', 'temp_out/UNY185.ospsAT_blast.xml', 'temp_out/UNY142.ospsAT_blast.xml', 'temp_out/UWI221.ospsAT_blast.xml', 'temp_out/K10.ospsAT_blast.xml', 'temp_out/UMA10.ospsAT_blast.xml', 'temp_out/ESI294.ospsAT_blast.xml', 'temp_out/UWI244.ospsAT_blast.xml', 'temp_out/URI65. ...
# temp_out/URI64.ospsAT_blast.xml
# URI64 AT11
# temp_out/UWI245.ospsAT_blast.xml
# UWI245 AT5
# temp_out/K74.ospsAT_blast.xml
# K74 AT1
# temp_out/ESI311.ospsAT_blast.xml
# ESI311 AT10
# temp_out/URI105.ospsAT_blast.xml
# URI105 AT1
# temp_out/ESI295.ospsAT_blast.xml
# ESI295 AT10
# temp_out/UWI220.ospsAT_blast.xml
# UWI220 AT6
# temp_out/UNY143.ospsAT_blast.xml
# UNY143 AT12
# temp_out/UMA11.ospsAT_blast.xml
# temp_out/K11.ospsAT_blast.xml
# K11 AT11
# temp_out/K30.ospsAT_blast.xml
# K30 AT9
# temp_out/UCT66.ospsAT_blast.xml
# UCT66 AT1
# temp_out/UCT110.ospsAT_blast.xml
# UCT110 AT11
# temp_out/UNY184.ospsAT_blast.xml
# UNY184 AT1
# temp_out/URI20.ospsAT_blast.xml
# URI20 AT7
# temp_out/UNY162.ospsAT_blast.xml
# UNY162 AT13
# temp_out/UMA4.ospsAT_blast.xml
# UMA4 AT11
# temp_out/5A18NP1-JBb08-E.ospsAT_blast.xml
# 5A18NP1-JBb08-E AT1
# temp_out/UNY203.ospsAT_blast.xml
# UNY203 AT7
# temp_out/UWI282.ospsAT_blast.xml
# UWI282 AT3
# temp_out/UWI264.ospsAT_blast.xml
# UWI264 AT10
# temp_out/UNY139.ospsAT_blast.xml
# UNY139 AT2
# temp_out/K7.ospsAT_blast.xml
# K7 AT1
# temp_out/BL546.ospsAT_blast.xml
# BL546 AT8
# temp_out/UNY176.ospsAT_blast.xml
# UNY176 AT2
# temp_out/UNY148.ospsAT_blast.xml
# UNY148 AT8
# temp_out/URI34.ospsAT_blast.xml
# temp_out/UNY190.ospsAT_blast.xml
# UNY190 AT2
# temp_out/UCT104.ospsAT_blast.xml
# UCT104 AT11
# temp_out/K24.ospsAT_blast.xml
# K24 AT7
# temp_out/URI89.ospsAT_blast.xml
# URI89 AT1
# temp_out/UWI270.ospsAT_blast.xml
# temp_out/UCT29.ospsAT_blast.xml
# UCT29 AT1
# temp_out/UNY217.ospsAT_blast.xml
# UNY217 AT14
# temp_out/URI111.ospsAT_blast.xml
# URI111 AT1
# temp_out/ESI305.ospsAT_blast.xml
# ESI305 AT2
# temp_out/K60.ospsAT_blast.xml
# K60 AT1
# temp_out/K86.ospsAT_blast.xml
# K86 AT1
# temp_out/UNY208.ospsAT_blast.xml
# UNY208 AT8
# temp_out/UNY132.ospsAT_blast.xml
# UNY132 AT9
# temp_out/UWI251.ospsAT_blast.xml
# UWI251 AT2
# temp_out/URI70.ospsAT_blast.xml
# URI70 AT2
# temp_out/UNY169.ospsAT_blast.xml
# UNY169 AT5
# temp_out/UNY157.ospsAT_blast.xml
# UNY157 AT2
# temp_out/UWI234.ospsAT_blast.xml
# UWI234 AT10
# temp_out/L113.ospsAT_blast.xml
# L113 AT10
# temp_out/MC105.ospsAT_blast.xml
# MC105 AT8
# temp_out/UNY136.ospsAT_blast.xml
# UNY136 AT5
# temp_out/UWI255.ospsAT_blast.xml
# UWI255 AT9
# temp_out/UCT32.ospsAT_blast.xml
# UCT32 AT11
# temp_out/K64.ospsAT_blast.xml
# K64 AT1
# temp_out/K82.ospsAT_blast.xml
# K82 AT11
# temp_out/ESI301.ospsAT_blast.xml
# ESI301 AT2
# temp_out/ESI285.ospsAT_blast.xml
# ESI285 AT2
# temp_out/UNY153.ospsAT_blast.xml
# UNY153 AT1
# temp_out/UWI230.ospsAT_blast.xml
# UWI230 AT15
# temp_out/B418.ospsAT_blast.xml
# B418 AT5
# temp_out/UCT121.ospsAT_blast.xml
# UCT121 AT2
# temp_out/UCT69.ospsAT_blast.xml
# UCT69 AT2
# temp_out/B500.ospsAT_blast.xml
# B500 AT9
# temp_out/UCT76.ospsAT_blast.xml
# UCT76 AT11
# temp_out/UNY172.ospsAT_blast.xml
# UNY172 AT12
# temp_out/UNY194.ospsAT_blast.xml
# UNY194 AT11
# temp_out/K3.ospsAT_blast.xml
# K3 AT1
# temp_out/ESI320.ospsAT_blast.xml
# ESI320 AT9
# temp_out/UNY213.ospsAT_blast.xml
# UNY213 AT6
# temp_out/UNY129.ospsAT_blast.xml
# UNY129 AT1
# temp_out/UWI274.ospsAT_blast.xml
# temp_out/URI55.ospsAT_blast.xml
# URI55 AT5
# temp_out/B31-K2.ospsAT_blast.xml
# B31-K2 AT1
# temp_out/UNY180.ospsAT_blast.xml
# UNY180 AT11
# temp_out/URI24.ospsAT_blast.xml
# URI24 AT1
# temp_out/UNY158.ospsAT_blast.xml
# UNY158 AT7
# temp_out/UNY166.ospsAT_blast.xml
# UNY166 AT13
# temp_out/UCT62.ospsAT_blast.xml
# UCT62 AT11
# temp_out/URI41.ospsAT_blast.xml
# URI41 AT1
# temp_out/UWI260.ospsAT_blast.xml
# UWI260 AT4
# temp_out/URI99.ospsAT_blast.xml
# URI99 AT13
# temp_out/UNY207.ospsAT_blast.xml
# temp_out/K89.ospsAT_blast.xml
# K89 AT9
# temp_out/5A18NP1-JBb08-A.ospsAT_blast.xml
# 5A18NP1-JBb08-A AT1
# temp_out/URI120.ospsAT_blast.xml
# URI120 AT1
# temp_out/ESI315.ospsAT_blast.xml
# ESI315 AT2
# temp_out/URI101.ospsAT_blast.xml
# URI101 AT1
# temp_out/UNY218.ospsAT_blast.xml
# UNY218 AT14
# temp_out/K70.ospsAT_blast.xml
# K70 AT11
# temp_out/URI60.ospsAT_blast.xml
# URI60 AT13
# temp_out/UWI241.ospsAT_blast.xml
# UWI241 AT7
# temp_out/URI86.ospsAT_blast.xml
# URI86 AT11
# temp_out/UMA15.ospsAT_blast.xml
# UMA15 AT11
# temp_out/K15.ospsAT_blast.xml
# K15 AT11
# temp_out/UWI224.ospsAT_blast.xml
# UWI224 AT8
# temp_out/UNY147.ospsAT_blast.xml
# temp_out/UNY179.ospsAT_blast.xml
# UNY179 AT11
# temp_out/BL082_H1.ospsAT_blast.xml
# BL082_H1 AT1
# temp_out/ESI291.ospsAT_blast.xml
# ESI291 AT2
# temp_out/UNY202.ospsAT_blast.xml
# UNY202 AT13
# temp_out/UNY138.ospsAT_blast.xml
# UNY138 AT13
# temp_out/UWI265.ospsAT_blast.xml
# UWI265 AT11
# temp_out/UWI283.ospsAT_blast.xml
# UWI283 AT3
# temp_out/URI44.ospsAT_blast.xml
# URI44 AT11
# temp_out/5A18NP1-JBb08-D.ospsAT_blast.xml
# 5A18NP1-JBb08-D AT1
# temp_out/MR616.ospsAT_blast.xml
# MR616 AT7
# temp_out/UMA5.ospsAT_blast.xml
# UMA5 AT13
# temp_out/UNY163.ospsAT_blast.xml
# UNY163 AT2
# temp_out/UNY185.ospsAT_blast.xml
# UNY185 AT11
# temp_out/UNY142.ospsAT_blast.xml
# UNY142 AT7
# temp_out/UWI221.ospsAT_blast.xml
# UWI221 AT8
# temp_out/K10.ospsAT_blast.xml
# K10 AT1
# temp_out/UMA10.ospsAT_blast.xml
# UMA10 AT2
# temp_out/ESI294.ospsAT_blast.xml
# ESI294 AT2
# temp_out/UWI244.ospsAT_blast.xml
# UWI244 AT10
# temp_out/URI65.ospsAT_blast.xml
# URI65 AT1
# temp_out/K75.ospsAT_blast.xml
# temp_out/UWI235.ospsAT_blast.xml
# UWI235 AT15
# temp_out/UNY168.ospsAT_blast.xml
# UNY168 AT8
# temp_out/UNY156.ospsAT_blast.xml
# UNY156 AT11
# temp_out/UNY209.ospsAT_blast.xml
# UNY209 AT9
# temp_out/URI71.ospsAT_blast.xml
# URI71 AT11
# temp_out/URI97.ospsAT_blast.xml
# URI97 AT11
# temp_out/UWI250.ospsAT_blast.xml
# UWI250 AT8
# temp_out/UNY133.ospsAT_blast.xml
# UNY133 AT6
# temp_out/ESI304.ospsAT_blast.xml
# ESI304 AT10
# temp_out/BL522.ospsAT_blast.xml
# BL522 AT12
# temp_out/URI88.ospsAT_blast.xml
# URI88 AT8
# temp_out/UWI271.ospsAT_blast.xml
# UWI271 AT2
# temp_out/UNY216.ospsAT_blast.xml
# UNY216 AT12
# temp_out/UNY191.ospsAT_blast.xml
# UNY191 AT8
# temp_out/UNY177.ospsAT_blast.xml
# UNY177 AT11
# temp_out/UNY149.ospsAT_blast.xml
# UNY149 AT11
# temp_out/K25.ospsAT_blast.xml
# K25 AT9
# temp_out/UCT73.ospsAT_blast.xml
# UCT73 AT11
# temp_out/K6.ospsAT_blast.xml
# K6 AT1
# temp_out/UNY212.ospsAT_blast.xml
# UNY212 AT11
# temp_out/XD1.ospsAT_blast.xml
# XD1 AT12
# temp_out/URI54.ospsAT_blast.xml
# URI54 AT7
# temp_out/UWI275.ospsAT_blast.xml
# UWI275 AT12
# temp_out/BL224.ospsAT_blast.xml
# BL224 AT11
# temp_out/K2.ospsAT_blast.xml
# K2 AT1
# temp_out/K21.ospsAT_blast.xml
# K21 AT5
# temp_out/UNY195.ospsAT_blast.xml
# UNY195 AT1
# temp_out/UNY173.ospsAT_blast.xml
# temp_out/BL091_B31E2_erpP.ospsAT_blast.xml
# BL091_B31E2_erpP AT1
# temp_out/UWI231.ospsAT_blast.xml
# UWI231 AT16
# temp_out/UNY152.ospsAT_blast.xml
# UNY152 AT15
# temp_out/ESI284.ospsAT_blast.xml
# ESI284 AT7
# temp_out/ESI300.ospsAT_blast.xml
# ESI300 AT10
# temp_out/URI114.ospsAT_blast.xml
# URI114 AT9
# temp_out/URI75.ospsAT_blast.xml
# URI75 AT1
# temp_out/B247.ospsAT_blast.xml
# B247 AT11
# temp_out/UWI254.ospsAT_blast.xml
# UWI254 AT8
# temp_out/URI93.ospsAT_blast.xml
# URI93 AT1
# temp_out/MC104.ospsAT_blast.xml
# MC104 AT8
# temp_out/UNY137.ospsAT_blast.xml
# temp_out/K83.ospsAT_blast.xml
# K83 AT11
# temp_out/ESI290.ospsAT_blast.xml
# ESI290 AT2
# temp_out/B331.ospsAT_blast.xml
# B331 AT9
# temp_out/UMA14.ospsAT_blast.xml
# UMA14 AT1
# temp_out/UNY146.ospsAT_blast.xml
# UNY146 AT11
# temp_out/UNY178.ospsAT_blast.xml
# UNY178 AT7
# temp_out/UWI225.ospsAT_blast.xml
# UWI225 AT6
# temp_out/K71.ospsAT_blast.xml
# K71 AT1
# temp_out/UWI240.ospsAT_blast.xml
# UWI240 AT12
# temp_out/URI87.ospsAT_blast.xml
# URI87 AT1
# temp_out/URI61.ospsAT_blast.xml
# URI61 AT1
# temp_out/URI100.ospsAT_blast.xml
# URI100 AT2
# temp_out/ESI314.ospsAT_blast.xml
# ESI314 AT2
# temp_out/UWI261.ospsAT_blast.xml
# UWI261 AT1
# temp_out/URI98.ospsAT_blast.xml
# URI98 AT11
# temp_out/URI40.ospsAT_blast.xml
# temp_out/B477.ospsAT_blast.xml
# temp_out/UNY206.ospsAT_blast.xml
# UNY206 AT13
# temp_out/UNY159.ospsAT_blast.xml
# UNY159 AT15
# temp_out/UNY167.ospsAT_blast.xml
# UNY167 AT9
# temp_out/UNY181.ospsAT_blast.xml
# UNY181 AT11
# temp_out/N40_HP.ospsAT_blast.xml
# N40_HP AT12
# temp_out/UCT115.ospsAT_blast.xml
# UCT115 AT8
# temp_out/UMA1.ospsAT_blast.xml
# UMA1 AT11
# temp_out/URI17.ospsAT_blast.xml
# URI17 AT2
# temp_out/UNY155.ospsAT_blast.xml
# UNY155 AT11
# temp_out/UWI236.ospsAT_blast.xml
# UWI236 AT7
# temp_out/UCT51.ospsAT_blast.xml
# UCT51 AT9
# temp_out/ESI307.ospsAT_blast.xml
# ESI307 AT2
# temp_out/URI72.ospsAT_blast.xml
# URI72 AT1
# temp_out/UNY130.ospsAT_blast.xml
# UNY130 AT11
# temp_out/URI94.ospsAT_blast.xml
# URI94 AT11
# temp_out/UWI253.ospsAT_blast.xml
# UWI253 AT8
# temp_out/K84.ospsAT_blast.xml
# K84 AT2
# temp_out/K62.ospsAT_blast.xml
# K62 AT8
# temp_out/UNY215.ospsAT_blast.xml
# UNY215 AT7
# temp_out/URI53.ospsAT_blast.xml
# URI53 AT9
# temp_out/BB-8.ospsAT_blast.xml
# BB-8 AT10
# temp_out/UWI272.ospsAT_blast.xml
# UWI272 AT1
# temp_out/ESI318.ospsAT_blast.xml
# ESI318 AT2
# temp_out/HB-19.ospsAT_blast.xml
# HB-19 AT9
# temp_out/UCT96.ospsAT_blast.xml
# UCT96 AT2
# temp_out/UCT106.ospsAT_blast.xml
# UCT106 AT13
# temp_out/K18.ospsAT_blast.xml
# K18 AT11
# temp_out/URI36.ospsAT_blast.xml
# URI36 AT9
# temp_out/UNY192.ospsAT_blast.xml
# UNY192 AT1
# temp_out/UNY174.ospsAT_blast.xml
# UNY174 AT2
# temp_out/UWI229.ospsAT_blast.xml
# UWI229 AT13
# temp_out/URI118.ospsAT_blast.xml
# URI118 AT11
# temp_out/UWI258.ospsAT_blast.xml
# UWI258 AT11
# temp_out/UWI280.ospsAT_blast.xml
# UWI280 AT8
# temp_out/URI79.ospsAT_blast.xml
# URI79 AT2
# temp_out/URI47.ospsAT_blast.xml
# URI47 AT11
# temp_out/K57.ospsAT_blast.xml
# K57 AT1
# temp_out/K69.ospsAT_blast.xml
# K69 AT1
# temp_out/UNY201.ospsAT_blast.xml
# UNY201 AT10
# temp_out/UNY160.ospsAT_blast.xml
# UNY160 AT11
# temp_out/URI22.ospsAT_blast.xml
# URI22 AT4
# temp_out/ESI297.ospsAT_blast.xml
# ESI297 AT2
# temp_out/K13.ospsAT_blast.xml
# K13 AT11
# temp_out/UMA13.ospsAT_blast.xml
# temp_out/UWI222.ospsAT_blast.xml
# UWI222 AT8
# temp_out/UNY141.ospsAT_blast.xml
# UNY141 AT6
# temp_out/UNY199.ospsAT_blast.xml
# UNY199 AT5
# temp_out/K76.ospsAT_blast.xml
# K76 AT8
# temp_out/K90.ospsAT_blast.xml
# K90 AT2
# temp_out/UWI279.ospsAT_blast.xml
# UWI279 AT6
# temp_out/UWI247.ospsAT_blast.xml
# UWI247 AT8
# temp_out/URI58.ospsAT_blast.xml
# URI58 AT9
# temp_out/URI107.ospsAT_blast.xml
# URI107 AT1
# temp_out/ESI313.ospsAT_blast.xml
# ESI313 AT2
# temp_out/UWI226.ospsAT_blast.xml
# UWI226 AT3
# temp_out/UNY145.ospsAT_blast.xml
# UNY145 AT1
# temp_out/URI39.ospsAT_blast.xml
# URI39 AT1
# temp_out/K17.ospsAT_blast.xml
# K17 AT11
# temp_out/UCT109.ospsAT_blast.xml
# UCT109 AT1
# temp_out/EU14_B89613.ospsAT_blast.xml
# EU14_B89613 AT2
# temp_out/URI103.ospsAT_blast.xml
# URI103 AT11
# temp_out/ESI317.ospsAT_blast.xml
# ESI317 AT2
# temp_out/UWI243.ospsAT_blast.xml
# UWI243 AT11
# temp_out/URI84.ospsAT_blast.xml
# temp_out/K72.ospsAT_blast.xml
# K72 AT11
# temp_out/B348.ospsAT_blast.xml
# B348 AT5
# temp_out/UNY205.ospsAT_blast.xml
# UNY205 AT9
# temp_out/UWI262.ospsAT_blast.xml
# temp_out/URI43.ospsAT_blast.xml
# URI43 AT1
# temp_out/URI122.ospsAT_blast.xml
# URI122 AT11
# temp_out/5A18NP1-JBb08-C.ospsAT_blast.xml
# 5A18NP1-JBb08-C AT1
# temp_out/ESI308.ospsAT_blast.xml
# ESI308 AT2
# temp_out/UMA2.ospsAT_blast.xml
# UMA2 AT6
# temp_out/B31-5A4.ospsAT_blast.xml
# B31-5A4 AT1
# temp_out/UWI239.ospsAT_blast.xml
# UWI239 AT3
# temp_out/UNY164.ospsAT_blast.xml
# UNY164 AT8
# temp_out/UNY182.ospsAT_blast.xml
# UNY182 AT11
# temp_out/ESI322.ospsAT_blast.xml
# ESI322 AT10
# temp_out/URI108.ospsAT_blast.xml
# URI108 AT2
# temp_out/URI57.ospsAT_blast.xml
# URI57 AT2
# temp_out/UWI248.ospsAT_blast.xml
# UWI248 AT8
# temp_out/UWI276.ospsAT_blast.xml
# UWI276 AT13
# temp_out/UNY211.ospsAT_blast.xml
# UNY211 AT11
# temp_out/UNY196.ospsAT_blast.xml
# UNY196 AT9
# temp_out/UNY170.ospsAT_blast.xml
# UNY170 AT1
# temp_out/UCT92.ospsAT_blast.xml
# UCT92 AT11
# temp_out/UCT74.ospsAT_blast.xml
# UCT74 AT1
# temp_out/K22.ospsAT_blast.xml
# temp_out/ESI28.ospsAT_blast.xml
# ESI28 AT7
# temp_out/K1.ospsAT_blast.xml
# K1 AT1
# temp_out/MR641.ospsAT_blast.xml
# MR641 AT8
# temp_out/ESI287.ospsAT_blast.xml
# ESI287 AT2
# temp_out/UMA9.ospsAT_blast.xml
# temp_out/UNY189.ospsAT_blast.xml
# UNY189 AT9
# temp_out/UNY151.ospsAT_blast.xml
# UNY151 AT8
# temp_out/UWI232.ospsAT_blast.xml
# UWI232 AT11
# temp_out/K80.ospsAT_blast.xml
# K80 AT5
# temp_out/UCT30.ospsAT_blast.xml
# UCT30 AT11
# temp_out/K66.ospsAT_blast.xml
# K66 AT1
# temp_out/K58.ospsAT_blast.xml
# K58 AT1
# temp_out/URI48.ospsAT_blast.xml
# URI48 AT13
# temp_out/EU51_B192411.ospsAT_blast.xml
# EU51_B192411 AT10
# temp_out/UNY134.ospsAT_blast.xml
# UNY134 AT13
# temp_out/UWI257.ospsAT_blast.xml
# UWI257 AT11
# temp_out/UWI269.ospsAT_blast.xml
# UWI269 AT8
# temp_out/URI90.ospsAT_blast.xml
# URI90 AT13
# temp_out/ESI303.ospsAT_blast.xml
# ESI303 AT2
# temp_out/BL206.ospsAT_blast.xml
# BL206 AT1
# temp_out/URI117.ospsAT_blast.xml
# URI117 AT11
# temp_out/K19.ospsAT_blast.xml
# K19 AT13
# temp_out/UWI228.ospsAT_blast.xml
# UWI228 AT11
# temp_out/UNY175.ospsAT_blast.xml
# UNY175 AT7
# temp_out/UNY193.ospsAT_blast.xml
# temp_out/URI37.ospsAT_blast.xml
# URI37 AT2
# temp_out/ESI319.ospsAT_blast.xml
# ESI319 AT10
# temp_out/UNY214.ospsAT_blast.xml
# UNY214 AT16
# temp_out/UWI273.ospsAT_blast.xml
# UWI273 AT3
# temp_out/MC123.ospsAT_blast.xml
# MC123 AT10
# temp_out/B483.ospsAT_blast.xml
# B483 AT13
# temp_out/URI52.ospsAT_blast.xml
# URI52 AT9
# temp_out/UWI252.ospsAT_blast.xml
# UWI252 AT10
# temp_out/UNY131.ospsAT_blast.xml
# UNY131 AT7
# temp_out/UCT35.ospsAT_blast.xml
# UCT35 AT7
# temp_out/URI112.ospsAT_blast.xml
# URI112 AT11
# temp_out/ESI306.ospsAT_blast.xml
# ESI306 AT2
# temp_out/UWI237.ospsAT_blast.xml
# UWI237 AT5
# temp_out/UNY154.ospsAT_blast.xml
# UNY154 AT11
# temp_out/UCT50.ospsAT_blast.xml
# UCT50 AT5
# temp_out/ESI312.ospsAT_blast.xml
# ESI312 AT10
# temp_out/BL515.ospsAT_blast.xml
# temp_out/URI67.ospsAT_blast.xml
# URI67 AT2
# temp_out/URI59.ospsAT_blast.xml
# URI59 AT7
# temp_out/URI81.ospsAT_blast.xml
# URI81 AT13
# temp_out/UWI278.ospsAT_blast.xml
# UWI278 AT8
# temp_out/UWI246.ospsAT_blast.xml
# UWI246 AT6
# temp_out/UMA12.ospsAT_blast.xml
# UMA12 AT1
# temp_out/K12.ospsAT_blast.xml
# K12 AT11
# temp_out/UNY140.ospsAT_blast.xml
# UNY140 AT5
# temp_out/UWI223.ospsAT_blast.xml
# UWI223 AT11
# temp_out/ESI26.ospsAT_blast.xml
# ESI26 AT7
# temp_out/ESI289.ospsAT_blast.xml
# ESI289 AT2
# temp_out/UMA7.ospsAT_blast.xml
# UMA7 AT13
# temp_out/URI23.ospsAT_blast.xml
# URI23 AT11
# temp_out/UNY187.ospsAT_blast.xml
# UNY187 AT2
# temp_out/UNY161.ospsAT_blast.xml
# UNY161 AT1
# temp_out/UCT83.ospsAT_blast.xml
# UCT83 AT11
# temp_out/UCT113.ospsAT_blast.xml
# UCT113 AT8
# temp_out/UWI281.ospsAT_blast.xml
# UWI281 AT14
# temp_out/URI78.ospsAT_blast.xml
# URI78 AT2
# temp_out/URI46.ospsAT_blast.xml
# URI46 AT11
# temp_out/UWI267.ospsAT_blast.xml
# UWI267 AT15
# temp_out/UNY200.ospsAT_blast.xml
# UNY200 AT1
# temp_out/K56.ospsAT_blast.xml
# K56 AT11
# temp_out/MR614.ospsAT_blast.xml
# temp_out/URI119.ospsAT_blast.xml
# URI119 AT1
# temp_out/URI19.ospsAT_blast.xml
# URI19 AT2
# temp_out/UNY183.ospsAT_blast.xml
# UNY183 AT9
# temp_out/UNY165.ospsAT_blast.xml
# UNY165 AT7
# temp_out/UWI238.ospsAT_blast.xml
# UWI238 AT10
# temp_out/UMA3.ospsAT_blast.xml
# UMA3 AT11
# temp_out/EU57_B190413.ospsAT_blast.xml
# EU57_B190413 AT7
# temp_out/ESI309.ospsAT_blast.xml
# ESI309 AT7
# temp_out/5A18NP1-JBb08-B.ospsAT_blast.xml
# 5A18NP1-JBb08-B AT1
# temp_out/URI219.ospsAT_blast.xml
# URI219 AT1
# temp_out/UNY204.ospsAT_blast.xml
# UNY204 AT12
# temp_out/URI42.ospsAT_blast.xml
# URI42 AT1
# temp_out/UWI263.ospsAT_blast.xml
# UWI263 AT10
# temp_out/URI63.ospsAT_blast.xml
# URI63 AT1
# temp_out/UWI242.ospsAT_blast.xml
# UWI242 AT1
# temp_out/URI85.ospsAT_blast.xml
# URI85 AT13
# temp_out/ESI288a.ospsAT_blast.xml
# ESI288a AT7
# temp_out/K73.ospsAT_blast.xml
# K73 AT1
# temp_out/B356.ospsAT_blast.xml
# B356 AT12
# temp_out/ESI316.ospsAT_blast.xml
# ESI316 AT10
# temp_out/UMA127.ospsAT_blast.xml
# temp_out/URI102.ospsAT_blast.xml
# URI102 AT1
# temp_out/ESI292.ospsAT_blast.xml
# ESI292 AT2
# temp_out/URI38.ospsAT_blast.xml
# URI38 AT14
# temp_out/MC149.ospsAT_blast.xml
# MC149 AT3
# temp_out/UNY144.ospsAT_blast.xml
# UNY144 AT15
# temp_out/UWI227.ospsAT_blast.xml
# UWI227 AT8
# temp_out/UMA16.ospsAT_blast.xml
# UMA16 AT2
# temp_out/K16.ospsAT_blast.xml
# K16 AT13
# temp_out/URI116.ospsAT_blast.xml
# URI116 AT13
# temp_out/K59.ospsAT_blast.xml
# K59 AT11
# temp_out/UCT31.ospsAT_blast.xml
# UCT31 AT1
# temp_out/UWI256.ospsAT_blast.xml
# UWI256 AT10
# temp_out/UWI268.ospsAT_blast.xml
# UWI268 AT9
# temp_out/URI91.ospsAT_blast.xml
# URI91 AT1
# temp_out/UNY135.ospsAT_blast.xml
# UNY135 AT9
# temp_out/BG001_C7.ospsAT_blast.xml
# BG001_C7 AT1
# temp_out/URI49.ospsAT_blast.xml
# URI49 AT6
# temp_out/URI77.ospsAT_blast.xml
# URI77 AT11
# temp_out/UWI233.ospsAT_blast.xml
# UWI233 AT7
# temp_out/UNY150.ospsAT_blast.xml
# UNY150 AT2
# temp_out/UNY188.ospsAT_blast.xml
# UNY188 AT11
# temp_out/UMA8.ospsAT_blast.xml
# UMA8 AT1
# temp_out/ESI286.ospsAT_blast.xml
# ESI286 AT2
# temp_out/ESI299.ospsAT_blast.xml
# ESI299 AT3
# temp_out/UNY171.ospsAT_blast.xml
# UNY171 AT6
# temp_out/UNY197.ospsAT_blast.xml
# UNY197 AT11
# temp_out/URI33.ospsAT_blast.xml
# URI33 AT5
# temp_out/UWI249.ospsAT_blast.xml
# UWI249 AT12
# temp_out/UWI277.ospsAT_blast.xml
# UWI277 AT13
# temp_out/URI56.ospsAT_blast.xml
# URI56 AT9
# temp_out/URI68.ospsAT_blast.xml
# URI68 AT13
# temp_out/UNY210.ospsAT_blast.xml
# UNY210 AT15
# temp_out/ESI323.ospsAT_blast.xml
# ESI323 AT10

# %%
# This is to check how many have been duplicated to see what is messing up above...
print(len(checked_types_ospc))
print(len(checked_types_AT))
duplicatesOC = checked_types_ospc[checked_types_ospc['Isolate'].duplicated()]
print(duplicatesOC)
duplicatesAT = checked_types_AT[checked_types_AT['Isolate'].duplicated()]
print(duplicatesAT)
# Out:
# 359
# 359
# Empty DataFrame
# Columns: [Isolate, ospc_newtype]
# Index: []
# Empty DataFrame
# Columns: [Isolate, AT_type]
# Index: []

# %%
pprint.pprint(known_types)
pprint.pprint(checked_types_ospc)
pprint.pprint(checked_types_AT)
# Out:
#              Isolate OspC_Type
# 0    5A18NP1-JBb08-A       NaN
# 1             UNY147         J
# 2    5A18NP1-JBb08-C       NaN
# 3    5A18NP1-JBb08-B       NaN
# 4    5A18NP1-JBb08-E       NaN
# ..               ...       ...
# 374              K60         A
# 375              K82         K
# 376              K11         K
# 377              K59         K
# 378              K69         A
#
# [379 rows x 2 columns]
#     Isolate ospc_newtype
# 0    ESI287         Bb_o
# 1    ESI292         Bb_o
# 2     URI78         Bb_o
# 3     UCT92            K
# 4    UWI231           E3
# ..      ...          ...
# 354  UNY162            N
# 355  UNY177            K
# 356   URI44            K
# 357   UCT35            G
# 358  UWI283            O
#
# [359 rows x 2 columns]
#     Isolate AT_type
# 0     URI64    AT11
# 1    UWI245     AT5
# 2       K74     AT1
# 3    ESI311    AT10
# 4    URI105     AT1
# ..      ...     ...
# 354  UWI277    AT13
# 355   URI56     AT9
# 356   URI68    AT13
# 357  UNY210    AT15
# 358  ESI323    AT10
#
# [359 rows x 2 columns]

# %%
if MERGE_RESULTS is True:
    merged_table = []
    # Merge the two tables on the 'Isolate' column
    merged_table = pandas.merge(known_types, checked_types_ospc, on='Isolate', how='left')
    print(merged_table)
    merged_table = pandas.merge(merged_table, checked_types_AT, on='Isolate', how='left')
    print(merged_table)
    for i in range(0, len(merged_table)):
        if pandas.isnull(merged_table.at[i, 'OspC_Type']):
            merged_table.at[i, 'OspC_Type'] = merged_table.at[i, 'ospc_newtype']
    merged_table.drop(columns=['ospc_newtype'], inplace=True)
    print(merged_table)
    print("Known types and new types tables have been merged!")
else:
    print("skipping merging")
# Out:
#              Isolate OspC_Type ospc_newtype
# 0    5A18NP1-JBb08-A       NaN            A
# 1             UNY147         J          NaN
# 2    5A18NP1-JBb08-C       NaN            A
# 3    5A18NP1-JBb08-B       NaN            A
# 4    5A18NP1-JBb08-E       NaN            A
# ..               ...       ...          ...
# 374              K60         A            A
# 375              K82         K            K
# 376              K11         K            K
# 377              K59         K            K
# 378              K69         A            A
#
# [379 rows x 3 columns]
#              Isolate OspC_Type ospc_newtype AT_type
# 0    5A18NP1-JBb08-A       NaN            A     AT1
# 1             UNY147         J          NaN     NaN
# 2    5A18NP1-JBb08-C       NaN            A     AT1
# 3    5A18NP1-JBb08-B       NaN            A     AT1
# 4    5A18NP1-JBb08-E       NaN            A     AT1
# ..               ...       ...          ...     ...
# 374              K60         A            A     AT1
# 375              K82         K            K    AT11
# 376              K11         K            K    AT11
# 377              K59         K            K    AT11
# 378              K69         A            A     AT1
#
# [379 rows x 4 columns]
#              Isolate OspC_Type AT_type
# 0    5A18NP1-JBb08-A         A     AT1
# 1             UNY147         J     NaN
# 2    5A18NP1-JBb08-C         A     AT1
# 3    5A18NP1-JBb08-B         A     AT1
# 4    5A18NP1-JBb08-E         A     AT1
# ..               ...       ...     ...
# 374              K60         A     AT1
# 375              K82         K    AT11
# 376              K11         K    AT11
# 377              K59         K    AT11
# 378              K69         A     AT1
#
# [379 rows x 3 columns]
# Known types and new types tables have been merged!

# %%
if FINALIZE_AND_WRITE_METADATA is True:
    #input_metadata.drop(columns=['OspC_Type'], inplace=True)
    output_metadata = pandas.merge(input_metadata, merged_table, on='Isolate', how='left')
    #print(output_metadata)
    output_metadata.to_csv("longread_metadata_v5.csv", index=False)
    print("metadata written!")
else:
    print("skipping writing final metadata")
# Out:
# metadata written!

# %%
print(output_metadata)
# Out:
#              Isolate MLST  RST_Type   Source Origin Location skin/blood_pairs  \
# 0    5A18NP1-JBb08-A    1       NaN  culture     US       NY              NaN
# 1             UNY147   34       3.0      NaN     US       NY              NaN
# 2    5A18NP1-JBb08-C    1       NaN  culture     US       NY              NaN
# 3    5A18NP1-JBb08-B    1       NaN  culture     US       NY              NaN
# 4    5A18NP1-JBb08-E    1       NaN  culture     US       NY              NaN
# ..               ...  ...       ...      ...    ...      ...              ...
# 374              K60    1       1.0      NaN     US       RI              NaN
# 375              K82    3       2.0      NaN     US       RI              NaN
# 376              K11    3       2.0      NaN     US       CT              NaN
# 377              K59    3       2.0      NaN     US       RI              NaN
# 378              K69    1       1.0      NaN     US       CT              NaN
#
#     Disseminated    method OspC_Type AT_type
# 0            NaN  nanopore         A     AT1
# 1              L  illumina         J     NaN
# 2            NaN  nanopore         A     AT1
# 3            NaN  nanopore         A     AT1
# 4            NaN  nanopore         A     AT1
# ..           ...       ...       ...     ...
# 374            D    hybrid         A     AT1
# 375            L    hybrid         K    AT11
# 376            D    hybrid         K    AT11
# 377            L    hybrid         K    AT11
# 378            L    hybrid         A     AT1
#
# [379 rows x 11 columns]

# %%
import pandas
output_metadata = pandas.read_csv('longread_metadata_v5.csv')
output_metadata[output_metadata["AT_type"] == "Bbis"]
# Out:
# Empty DataFrame
# Columns: [Isolate, MLST, RST_Type, Source, Origin, Location, skin/blood_pairs, Disseminated, method, OspC_Type, AT_type]
# Index: []

# %%
output_metadata[output_metadata["OspC_Type"] == "Bbis"]
# Out:
# Empty DataFrame
# Columns: [Isolate, MLST, RST_Type, Source, Origin, Location, skin/blood_pairs, Disseminated, method, OspC_Type, AT_type]
# Index: []
